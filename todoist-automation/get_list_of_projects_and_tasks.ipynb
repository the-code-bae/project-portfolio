# %%
from api_token import token
import todoist as td
import pandas as pd
# import time
import datetime

# %%
api = td.TodoistAPI(token)
api.sync()
# Out:
# {'collaborator_states': [],
#  'collaborators': [],
#  'day_orders': {},
#  'day_orders_timestamp': '1344642991.1',
#  'due_exceptions': [],
#  'filters': [],
#  'full_sync': False,
#  'items': [{'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4442841422,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 7,
#    'collapsed': 0,
#    'content': 'Change bedsheets',
#    'date_added': '2020-07-26T17:54:17Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-09',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every 2 sat',
#     'timezone': None},
#    'id': 4061242052,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 15121148,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 2,
#    'collapsed': 0,
#    'content': 'Visit Grandma',
#    'date_added': '2020-11-21T17:02:31Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 3 2021',
#     'timezone': None},
#    'id': 4354156271,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 30060955,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 4,
#    'collapsed': 0,
#    'content': '**05** Add to interview prep doc',
#    'date_added': '2020-12-09T20:40:39Z',
#    'date_completed': '2020-12-30T21:05:24Z',
#    'day_order': -1,
#    'due': {'date': '2020-12-30',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Dec 30',
#     'timezone': None},
#    'id': 4402082621,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384015,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4205920808,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4205921462,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4205922201,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4205923262,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4205925365,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4205925710,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4354210940,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4354211431,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 3,
#    'collapsed': 0,
#    'content': '**05** Add to interview prep pack',
#    'date_added': '2020-09-26T06:35:16Z',
#    'date_completed': '2020-12-30T21:11:12Z',
#    'day_order': -1,
#    'due': {'date': '2020-12-30',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Dec 30',
#     'timezone': None},
#    'id': 4205919498,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [2155605676],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384015,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': 'First draft of company mission statement',
#    'date_added': '2020-12-30T21:54:27Z',
#    'date_completed': '2020-12-30T22:22:09Z',
#    'day_order': -1,
#    'due': None,
#    'id': 4450414650,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': 4299954424,
#    'priority': 1,
#    'project_id': 2240484947,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': "**01b** Review your job description and provide examples for how you've met the requirements of your JD",
#    'date_added': '2020-12-20T21:30:50Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 3 2021',
#     'timezone': None},
#    'id': 4429214406,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384005,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4390450930,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4354218366,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192287053,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 5,
#    'collapsed': 0,
#    'content': 'Call dad',
#    'date_added': '2020-12-26T20:54:56Z',
#    'date_completed': '2021-01-01T12:38:10Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-01',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 1 2021',
#     'timezone': None},
#    'id': 4441236855,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 30060955,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 4,
#    'collapsed': 0,
#    'content': 'Call Mum',
#    'date_added': '2020-11-21T17:05:07Z',
#    'date_completed': '2021-01-01T12:38:11Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-01',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 1 2021',
#     'timezone': None},
#    'id': 4354160771,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 30060955,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**05** Renew Address services for IBE Analytics Ltd January renewal reminder.',
#    'date_added': '2020-12-19T11:30:24Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-04',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 4 2021',
#     'timezone': None},
#    'id': 4426392511,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384017,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': 'Fix 12 week year spreadsheet',
#    'date_added': '2020-12-31T19:15:50Z',
#    'date_completed': '2021-01-01T13:10:39Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-01',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': '1 Jan 2021',
#     'timezone': None},
#    'id': 4452051922,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': 'Change tv license for mum',
#    'date_added': '2020-11-08T13:10:05Z',
#    'date_completed': '2021-01-01T13:25:44Z',
#    'day_order': -1,
#    'due': None,
#    'id': 4318653721,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': 4332598593,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384015,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**04** Set up a [new tv licence](https://www.tvlicensing.co.uk/cs/pay-for-your-tv-licence/index.app) for mum',
#    'date_added': '2020-11-13T10:37:08Z',
#    'date_completed': '2021-01-01T13:25:44Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-01',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 1',
#     'timezone': None},
#    'id': 4332598593,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [2155605676],
#    'parent_id': None,
#    'priority': 4,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384015,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 6,
#    'collapsed': 0,
#    'content': '**Layouts 2.1.** How to tackle house layout',
#    'date_added': '2020-12-27T20:20:27Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'id': 4442866731,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': 4425432818,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 15085763,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 2,
#    'collapsed': 0,
#    'content': '**RP01:** Write the company mission statement',
#    'date_added': '2020-10-31T23:13:36Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'id': 4299954424,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240484947,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 1,
#    'content': '**00** Weekly food shop 🌽 & other bits',
#    'date_added': '2020-08-29T11:06:30Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-08',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every week',
#     'timezone': None},
#    'id': 4135956061,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 15121148,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 4,
#    'collapsed': 0,
#    'content': '**06** Give yourself a pedicure',
#    'date_added': '2020-11-30T08:39:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 3',
#     'timezone': None},
#    'id': 4375003587,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 1,
#    'content': '**04** Regular finance review',
#    'date_added': '2020-07-23T10:12:12Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-08',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 8',
#     'timezone': None},
#    'id': 4055128999,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 30060955,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4452858468,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 5,
#    'collapsed': 0,
#    'content': '**03** [Fifi Renovation Course](https://fifimcgee.co.uk/how-to-renovate-home)',
#    'date_added': '2020-12-18T21:22:53Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4425432818,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 15085763,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**04a** Bathroom Mood Board',
#    'date_added': '2020-12-27T20:02:33Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4442838259,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': 4354100562,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384001,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 5,
#    'collapsed': 0,
#    'content': '**06** Hoover and mop 🧼',
#    'date_added': '2020-07-26T17:52:37Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-10',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every other sun',
#     'timezone': None},
#    'id': 4061239714,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 15121148,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 5,
#    'collapsed': 0,
#    'content': '**05b** File nails',
#    'date_added': '2020-12-03T06:05:28Z',
#    'date_completed': '2021-01-01T23:04:26Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4384309791,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 4,
#    'collapsed': 0,
#    'content': '**02** [100 days of code](https://www.udemy.com/course/100-days-of-code/learn/)',
#    'date_added': '2020-12-14T03:39:48Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every day',
#     'timezone': None},
#    'id': 4411952967,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 15085763,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4147823735,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4152566420,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4152741689,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4164872481,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4164221609,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4167311738,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4135956252,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4164275380,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4165249825,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192288598,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192287918,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4164231084,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192632674,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192435265,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4194324964,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192411059,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4146676744,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4203405636,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192535391,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4208122803,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192411064,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4192411419,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4225236489,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4225501609,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4225501769,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4203405211,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4201554080,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4146677209,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4290877634,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4146676811,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4330541553,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4146676434,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4371969819,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4364260844,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4367615210,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4410688634,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4385990498,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4385990344,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4414014793,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4423753879,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4433142956,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4385990029,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4426235848,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4442298720,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4442282674,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4385990360,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4326902573,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4371271491,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4354218474,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4330529450,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4194324958,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4164860415,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
# ...
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4146677582,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': None,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 0,
#    'collapsed': 0,
#    'content': '',
#    'date_added': '1970-01-01T00:00:00Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'due_is_recurring': False,
#    'id': 4360718261,
#    'in_history': 0,
#    'is_deleted': 1,
#    'labels': [],
#    'legacy_project_id': 0,
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 0,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**00** Plan my week',
#    'date_added': '2020-07-21T17:41:12Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every sunday',
#     'timezone': None},
#    'id': 4051402125,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 4,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 15085763,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 3,
#    'collapsed': 0,
#    'content': '**01** Take progress pics',
#    'date_added': '2020-11-23T07:03:09Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every other sun',
#     'timezone': None},
#    'id': 4357255394,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 9,
#    'collapsed': 0,
#    'content': '**01a** Laundry and bathroom items 👖',
#    'date_added': '2020-07-26T17:56:26Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-08',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every fri',
#     'timezone': None},
#    'id': 4061245089,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240717407,
#    'responsible_uid': None,
#    'section_id': 15121148,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**z: Errand 01:** Nancy Birthday Present order',
#    'date_added': '2020-09-12T10:30:21Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 3',
#     'timezone': None},
#    'id': 4169208802,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [2155605676],
#    'parent_id': None,
#    'priority': 4,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384044,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**00a** Cook rice',
#    'date_added': '2021-01-01T22:42:05Z',
#    'date_completed': '2021-01-02T13:21:20Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4453785278,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 1,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': 'Collect glasses from specsavers',
#    'date_added': '2021-01-01T18:12:07Z',
#    'date_completed': '2021-01-02T13:22:33Z',
#    'day_order': -1,
#    'due': {'date': '2021-01-02T10:00:00',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2 10:00 AM',
#     'timezone': None},
#    'id': 4453341469,
#    'in_history': 1,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 30384044,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 2,
#    'collapsed': 0,
#    'content': '**00** Plan my day',
#    'date_added': '2020-11-22T12:29:32Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every day',
#     'timezone': None},
#    'id': 4355453459,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 4,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 15085763,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 2,
#    'collapsed': 0,
#    'content': '**00z** Make salad',
#    'date_added': '2021-01-01T22:42:36Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 3',
#     'timezone': None},
#    'id': 4453786016,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 1,
#    'collapsed': 0,
#    'content': '**05 RP01a:** Clean Up/Second draft of company mission statement',
#    'date_added': '2020-12-30T22:22:23Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4450463848,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': 4299954424,
#    'priority': 1,
#    'project_id': 2240484947,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 3,
#    'collapsed': 1,
#    'content': '**05b RP02:** What is the product/service offering?',
#    'date_added': '2020-12-27T14:21:55Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4442267142,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240484947,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 7,
#    'collapsed': 0,
#    'content': '**05a** Draft product/service offering',
#    'date_added': '2021-01-01T13:29:19Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4452891321,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': 4442267142,
#    'priority': 1,
#    'project_id': 2240484947,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 3,
#    'collapsed': 0,
#    'content': '**06** Finish off 12 Week Year Template',
#    'date_added': '2021-01-02T13:59:34Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4454963604,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 4,
#    'collapsed': 0,
#    'content': '**0z** Research how to make money on etsy using digital downloads',
#    'date_added': '2021-01-02T14:00:17Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-02',
#     'is_recurring': False,
#     'lang': 'en',
#     'string': 'Jan 2',
#     'timezone': None},
#    'id': 4454964753,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 9,
#    'collapsed': 0,
#    'content': "Create a script that will automatically add new gospel song you've 'liked' to your gospel playlist",
#    'date_added': '2021-01-02T14:27:54Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': None,
#    'id': 4455014483,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2250742579,
#    'responsible_uid': None,
#    'section_id': None,
#    'sync_id': None,
#    'user_id': 28966387},
#   {'added_by_uid': 28966387,
#    'assigned_by_uid': None,
#    'checked': 0,
#    'child_order': 3,
#    'collapsed': 0,
#    'content': "**01** Make notes on Data Engineer JD's",
#    'date_added': '2020-12-23T10:55:21Z',
#    'date_completed': None,
#    'day_order': -1,
#    'due': {'date': '2021-01-03',
#     'is_recurring': True,
#     'lang': 'en',
#     'string': 'every day',
#     'timezone': None},
#    'id': 4435958173,
#    'in_history': 0,
#    'is_deleted': 0,
#    'labels': [],
#    'parent_id': None,
#    'priority': 1,
#    'project_id': 2240338076,
#    'responsible_uid': None,
#    'section_id': 15085763,
#    'sync_id': None,
#    'user_id': 28966387}],
#  'labels': [],
#  'live_notifications': [],
#  'live_notifications_last_read_id': 2344876041,
#  'notes': [{'content': 'https://docs.google.com/spreadsheets/d/1KFuTPSYgl6HpN7N1tyTmv9QzHVAxiAjtxFpstcZSyIs/edit#gid=0',
#    'file_attachment': None,
#    'id': 2740493593,
#    'is_deleted': 0,
#    'item_id': 4435958173,
#    'posted': '2020-12-30T16:27:18Z',
#    'posted_uid': 28966387,
#    'project_id': 2240338076,
#    'reactions': None,
#    'uids_to_notify': []},
#   {'content': "Taken from Zapier application\n\n- In 3-5 sentences, tell us why you'd be a good fit for this role? *\n\n- Tell us about a time you mentored a junior data colleague towards success in a complex piece of analysis, research or experimentation. What approach did you use in your mentoring? How did your involvement affect the outcome?  *\n\n- Describe a time when you detected a problem in data processing code and the steps you took to determine where the problem was.  *\n\n- What are you really good at professionally? What are you seeking to improve at? What are you not interested in doing regularly?  *\n\n- Please describe a programming function, object or stored procedure you're proud to have created that helped move data or perform analysis. Feel free to link to non-sensitive source code and documentation via github gist, pastebin or similar if you'd like to display the code. *\n\n- Optional: Is there anything else you'd like us to know about you?\n",
#    'file_attachment': None,
#    'id': 2730299288,
#    'is_deleted': 0,
#    'item_id': 4402082621,
#    'posted': '2020-12-09T20:40:39Z',
#    'posted_uid': 28966387,
#    'project_id': 2240338076,
#    'reactions': None,
#    'uids_to_notify': None},
#   {'content': 'readdlespark://bl=QTpuaWJlMTJAbGl2ZS5jb207SUQ6MC4xLjE1Qy5GNTYuMUQ2RTAzOTNEM0VCQzQ0%0D%0ALjBAb21wLmZhc2hpb24uYXNvcy5jb207MzU3OTE2NDMwMA%3D%3D',
#    'file_attachment': None,
#    'id': 2741040839,
#    'is_deleted': 1,
#    'item_id': 4452858468,
#    'posted': '2021-01-01T13:00:56Z',
#    'posted_uid': 28966387,
#    'project_id': 2240338076,
#    'reactions': None,
#    'uids_to_notify': None},
#   {'content': '',
#    'file_attachment': {'file_name': 'image.jpg',
#     'file_size': 48740,
#     'file_type': 'image/jpeg',
#     'file_url': 'https://files.todoist.com/user_upload/v2/2174980519/file.jpg',
#     'image': 'https://files.todoist.com/user_upload/v2/2174980519/file.jpg',
#     'image_height': 667,
#     'image_width': 375,
#     'resource_type': 'image',
#     'upload_state': 'completed'},
#    'id': 2711530263,
#    'is_deleted': 0,
#    'item_id': 4318653721,
#    'posted': '2020-11-08T13:23:03Z',
#    'posted_uid': 28966387,
#    'project_id': 2240338076,
#    'reactions': None,
#    'uids_to_notify': []},
#   {'content': "Is there a genre 'attribute', 'variable' or 'property' which tells you the genre a song falls into? ",
#    'file_attachment': None,
#    'id': 2741294438,
#    'is_deleted': 0,
#    'item_id': 4455014483,
#    'posted': '2021-01-02T14:28:41Z',
#    'posted_uid': 28966387,
#    'project_id': 2250742579,
#    'reactions': None,
#    'uids_to_notify': []}],
#  'project_notes': [],
#  'projects': [],
#  'reminders': [{'due': None,
#    'id': 2310625544,
#    'is_deleted': 1,
#    'item_id': 0,
#    'legacy_item_id': 0,
#    'minute_offset': 30,
#    'notify_uid': 28966387,
#    'service': 'push',
#    'type': 'relative'},
#   {'due': None,
#    'id': 2326660854,
#    'is_deleted': 1,
#    'item_id': 0,
#    'legacy_item_id': 0,
#    'minute_offset': 30,
#    'notify_uid': 28966387,
#    'service': 'push',
#    'type': 'relative'}],
#  'sections': [],
#  'stats': {'completed_count': 852,
#   'days_items': [{'date': '2021-01-02', 'total_completed': 4}],
#   'week_items': [{'from': '2020-12-28',
#     'to': '2021-01-03',
#     'total_completed': 42}]},
#  'sync_token': 'MbUOnUUq91ioLzFWS7n7ZKNWxiMZ4VaCLrtL9TQCk57RLwmFgepYbvbVqdqunuZkSLraOrj1hHEYXExvlBCgxY5FIy03_6ZfWZ8pjc309a5ZJmc',
#  'temp_id_mapping': {},
#  'user': {'auto_reminder': 10,
#   'avatar_big': 'https://dcff1xvirvpfp.cloudfront.net/a795b2d5d32d45ca8113f294f235113d_big.jpg',
#   'avatar_medium': 'https://dcff1xvirvpfp.cloudfront.net/a795b2d5d32d45ca8113f294f235113d_medium.jpg',
#   'avatar_s640': 'https://dcff1xvirvpfp.cloudfront.net/a795b2d5d32d45ca8113f294f235113d_s640.jpg',
#   'avatar_small': 'https://dcff1xvirvpfp.cloudfront.net/a795b2d5d32d45ca8113f294f235113d_small.jpg',
#   'business_account_id': None,
#   'daily_goal': 5,
#   'date_format': 1,
#   'dateist_inline_disabled': False,
#   'dateist_lang': None,
#   'days_off': [6, 7],
#   'default_reminder': 'email',
#   'email': 'nibe0993@gmail.com',
#   'features': {'beta': 1,
#    'dateist_inline_disabled': False,
#    'dateist_lang': None,
#    'has_push_reminders': True,
#    'karma_disabled': False,
#    'karma_vacation': False,
#    'restriction': 3},
#   'full_name': 'Maka I',
#   'id': 28966387,
#   'image_id': 'a795b2d5d32d45ca8113f294f235113d',
#   'inbox_project': 2240336392,
#   'is_biz_admin': False,
#   'is_premium': True,
#   'join_date': '2020-07-19T19:10:29Z',
#   'karma': 10644.0,
#   'karma_trend': 'up',
#   'lang': 'en',
#   'mobile_host': None,
#   'mobile_number': None,
#   'next_week': 1,
#   'premium_until': '2021-07-19T19:44:52Z',
#   'share_limit': 25,
#   'sort_order': 0,
#   'start_day': 1,
#   'start_page': 'overdue, today',
#   'theme': 8,
#   'time_format': 1,
#   'token': '42cf736de95803e0de87a8b9043eea46799b64ee',
#   'tz_info': {'gmt_string': '+00:00',
#    'hours': 0,
#    'is_dst': 0,
#    'minutes': 0,
#    'timezone': 'Europe/London'},
#   'unique_prefix': 8,
#   'websocket_url': 'wss://ws.todoist.com/ws?token=fe27aca8f9238f63',
#   'weekly_goal': 35},
#  'view_options': []}

# %%
# this will convert from a individual todoist projects to dictionary
projects = [project.data for project in api.state['projects']]

# %%
# use dictionary to create data frame
df_projects = pd.DataFrame(projects)

# view data frame
df_projects.head(20)
# Out:
#     child_order  collapsed  color  has_more_notes          id inbox_project  \
# 0             0          0     48           False  2240336392          True
# 1             1          0     31           False  2240338076           NaN
# 2             2          0     46           False  2250738735           NaN
# 3             3          0     33           False  2250738747           NaN
# 4             4          0     34           False  2250738761           NaN
# 5             5          0     47           False  2250741928           NaN
# 6             6          0     47           False  2250742579           NaN
# 7             7          0     31           False  2240553789           NaN
# 8             8          0     30           False  2240717407           NaN
# 9             9          0     32           False  2240338162           NaN
# 10           10          0     38           False  2240484947           NaN
#
#     is_archived  is_deleted  is_favorite                       name parent_id  \
# 0             0           0            0                      Inbox      None
# 1             0           0            0                ❶ This Week      None
# 2             0           0            0                ❷ Next Week      None
# 3             0           0            0               ❸ This Month      None
# 4             0           0            0               ❹ Next Month      None
# 5             0           0            0  ❺ Further Than Next Month      None
# 6             0           0            0            🧠 Project Ideas      None
# 7             0           0            0                🚧 Backlog 🚧      None
# 8             0           0            0                 ⏱ Routines      None
# 9             0           0            0                      🥓 JET      None
# 10            0           0            0           🏡 Reign Property      None
#
#     shared sync_id
# 0    False    None
# 1    False    None
# 2    False    None
# 3    False    None
# 4    False    None
# 5    False    None
# 6    False    None
# 7    False    None
# 8    False    None
# 9    False    None
# 10   False    None

# %%
# Create tasks database
tasks = [task.data for task in api.state['items']]

# %%
df_tasks = pd.DataFrame(tasks)
df_tasks[df_tasks['checked'] ==1].head(10)
# Out:
#      added_by_uid assigned_by_uid  checked  child_order  collapsed  \
# 152      28966387            None        1            3          0
# 165      28966387            None        1            1          0
# 170      28966387            None        1            1          0
# 194      28966387            None        1            1          0
# 196      28966387            None        1            4          0
# 225      28966387            None        1            5          0
# 231      28966387            None        1            4          0
# 251      28966387            None        1            5          0
# 265      28966387            None        1            6          0
# 266      28966387            None        1            5          0
#
#                                                content            date_added  \
# 152                  **05** Add to interview prep pack  2020-09-26T06:35:16Z
# 165                          Change tv license for mum  2020-11-08T13:10:05Z
# 170  **04** Set up a [new tv licence](https://www.t...  2020-11-13T10:37:08Z
# 194      **08** 2021 Vision Board + Aspirational Goals  2020-11-21T17:00:50Z
# 196                                           Call Mum  2020-11-21T17:05:07Z
# 225                                 **05b** File nails  2020-12-03T06:05:28Z
# 231                   **05** Add to interview prep doc  2020-12-09T20:40:39Z
# 251                **07** 2021 Finance + Savings Goals  2020-12-20T21:33:11Z
# 265                               Order protein powder  2020-12-24T10:59:18Z
# 266                                           Call dad  2020-12-26T20:54:56Z
#
#            date_completed  day_order  \
# 152  2020-12-30T21:11:12Z         -1
# 165  2021-01-01T13:25:44Z         -1
# 170  2021-01-01T13:25:44Z         -1
# 194  2020-12-28T20:44:31Z         -1
# 196  2021-01-01T12:38:11Z         -1
# 225  2021-01-01T23:04:26Z         -1
# 231  2020-12-30T21:05:24Z         -1
# 251  2020-12-28T19:10:23Z         -1
# 265  2020-12-29T10:07:54Z         -1
# 266  2021-01-01T12:38:10Z         -1
#
#                                                    due  ... in_history  \
# 152  {'date': '2020-12-30', 'is_recurring': False, ...  ...          1
# 165                                               None  ...          1
# 170  {'date': '2021-01-01', 'is_recurring': False, ...  ...          1
# 194  {'date': '2020-12-28', 'is_recurring': False, ...  ...          1
# 196  {'date': '2021-01-01', 'is_recurring': False, ...  ...          1
# 225  {'date': '2021-01-02', 'is_recurring': False, ...  ...          1
# 231  {'date': '2020-12-30', 'is_recurring': False, ...  ...          1
# 251  {'date': '2020-12-28', 'is_recurring': False, ...  ...          1
# 265  {'date': '2021-01-07', 'is_recurring': False, ...  ...          1
# 266  {'date': '2021-01-01', 'is_recurring': False, ...  ...          1
#
#      is_deleted        labels     parent_id priority  project_id  \
# 152           0  [2155605676]           NaN        1  2240338076
# 165           0            []  4.332599e+09        1  2240338076
# 170           0  [2155605676]           NaN        4  2240338076
# 194           0  [2155605676]           NaN        1  2240338076
# 196           0            []           NaN        1  2240717407
# 225           0            []           NaN        1  2240717407
# 231           0            []           NaN        1  2240338076
# 251           0            []           NaN        1  2240338076
# 265           0            []           NaN        1  2250738735
# 266           0            []           NaN        1  2240717407
#
#      responsible_uid  section_id sync_id   user_id
# 152             None  30384015.0    None  28966387
# 165             None  30384015.0    None  28966387
# 170             None  30384015.0    None  28966387
# 194             None  30384001.0    None  28966387
# 196             None  30060955.0    None  28966387
# 225             None         NaN    None  28966387
# 231             None  30384015.0    None  28966387
# 251             None  30384001.0    None  28966387
# 265             None         NaN    None  28966387
# 266             None  30060955.0    None  28966387
#
# [10 rows x 22 columns]

# %%
today = datetime.date.today()
yesterday = today - datetime.timedelta(days = 1)
tomorrow = today + datetime.timedelta(days = 1) 
print('Yesterday : ',yesterday)
print('Today : ',today)
print('Tomorrow : ',tomorrow)
yday_start = str(yesterday)+"T00:00:00Z"
yday_end = str(yesterday)+"T23:59:59Z"
print(yday_start)
print(yday_end)
# Out:
# Yesterday :  2021-01-01
# Today :  2021-01-02
# Tomorrow :  2021-01-03
# 2021-01-01T00:00:00Z
# 2021-01-01T23:59:59Z

# %%
# Get list of tasks completed in the last day
print(len(api.completed.get_all(since = yday_start, until = yday_end)['items']))
for item in api.completed.get_all(since = yday_start, until = yday_end)['items']:
    print (item)
# print(api.completed.get_all(since = yday))
# for d in api.completed.get_all(since ='2020-12-29T00:00')["projects"]:
#     print(d)
# Out:
# 11
# {'completed_date': '2021-01-01T23:17:35Z', 'content': '**02** [100 days of code](https://www.udemy.com/course/100-days-of-code/learn/)', 'id': 4169634811, 'meta_data': None, 'project_id': 2240338076, 'task_id': 4411952967, 'user_id': 28966387}
# {'completed_date': '2021-01-01T23:04:29Z', 'content': '**05b** File nails', 'id': 4169621549, 'meta_data': None, 'project_id': 2240717407, 'task_id': 4384309791, 'user_id': 28966387}
# {'completed_date': '2021-01-01T21:25:00Z', 'content': "**01** Make notes on Data Engineer JD's", 'id': 4169505119, 'meta_data': None, 'project_id': 2240338076, 'task_id': 4435958173, 'user_id': 28966387}
# {'completed_date': '2021-01-01T19:59:50Z', 'content': '**00** Weekly food shop 🌽 & other bits', 'id': 4169398991, 'meta_data': None, 'project_id': 2240717407, 'task_id': 4135956061, 'user_id': 28966387}
# {'completed_date': '2021-01-01T18:07:16Z', 'content': '**00** Plan my day', 'id': 4169254218, 'meta_data': None, 'project_id': 2240338076, 'task_id': 4355453459, 'user_id': 28966387}
# {'completed_date': '2021-01-01T13:25:48Z', 'content': '**04** Set up a [new tv licence](https://www.tvlicensing.co.uk/cs/pay-for-your-tv-licence/index.app) for mum @personal', 'id': 4168897147, 'meta_data': None, 'project_id': 2240338076, 'task_id': 4332598593, 'user_id': 28966387}
# {'completed_date': '2021-01-01T13:25:48Z', 'content': 'Change tv license for mum', 'id': 4168897146, 'meta_data': None, 'project_id': 2240338076, 'task_id': 4318653721, 'user_id': 28966387}
# {'completed_date': '2021-01-01T13:10:44Z', 'content': 'Fix 12 week year spreadsheet', 'id': 4168882399, 'meta_data': None, 'project_id': 2240338076, 'task_id': 4452051922, 'user_id': 28966387}
# {'completed_date': '2021-01-01T12:38:16Z', 'content': 'Call Mum', 'id': 4168851328, 'meta_data': None, 'project_id': 2240717407, 'task_id': 4354160771, 'user_id': 28966387}
# {'completed_date': '2021-01-01T12:38:16Z', 'content': 'Call dad', 'id': 4168851326, 'meta_data': None, 'project_id': 2240717407, 'task_id': 4441236855, 'user_id': 28966387}
# {'completed_date': '2021-01-01T12:38:00Z', 'content': '**01a:** Laundry and bathroom items 👖', 'id': 4168851111, 'meta_data': None, 'project_id': 2240717407, 'task_id': 4061245089, 'user_id': 28966387}

# %%
# Create tasks activities
