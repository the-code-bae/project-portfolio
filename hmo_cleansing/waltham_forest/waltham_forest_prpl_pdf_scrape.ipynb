# %%
import tabula
import re
import pandas as pd
import os
from oauth2client.service_account import ServiceAccountCredentials
import gspread

# %%
# Change pdf name
df = tabula.read_pdf("20201126 Waltham Forest Privated Public Register November 2020.pdf"
                     , pages='all'
                     , pandas_options = {'header': None})

# %%
len(df) #should total the amount of pages in the document
# Out:
# 76

# %%
class SplitFields:
    def __init__(self, field):
        self.field = field
    
    @property
    def split_list(self):
        return re.split(r'([A-Z]{1,2}[0-9R][0-9A-Z]? [0-9][A-Z]{2})', self.field)
    
    @property
    def property_address(self):
        return ''.join(self.split_list[:len(self.split_list)-1])
    
    @property
    def licence_holder(self):
        return self.split_list[-1]

# %%
complete_register = pd.concat(df, ignore_index=True)

# remove first line which contains header data
complete_register.drop([0], inplace=True)

# reset index after dropping row
complete_register.reset_index(drop=True, inplace=True)

# get property address from field
complete_register[5] = complete_register[1].apply(lambda x: SplitFields(x).property_address)

# get licence holder from field
complete_register[6] = complete_register.apply(lambda x: SplitFields(x[1]).licence_holder if pd.isnull(x[2]) else x[2], axis=1)

# %%
# created a df with columns to keep
final_df = complete_register[[0,5,6,3,4]].copy()

# %%
# rename columns
final_df.columns = ['ref_no', 'property_address', 'licence_holder', 'start_date', 'end_date']

# %%
final_df.head()
# Out:
#   ref_no                                   property_address  \
# 0  14531              43 Chester Road, Walthamstow, E17 7HP
# 1  20502          Flat 1, 8 Goldsmith Road, Leyton, E10 5HA
# 2  20881              Flat 2, 79 Park Road, Leyton, E10 7BZ
# 3  20932  Ground Floor Flat, 23 Cornwallis Road, Waltham...
# 4  21254   Flat 3, 62 St James Street, Walthamstow, E17 7PE
#
#        licence_holder  start_date    end_date
# 0   Mr Lahrie Mohamed  15/03/2018  15/03/2023
# 1   Mr Lahrie Mohamed  12/05/2017  12/05/2022
# 2   Mr Lahrie Mohamed  01/11/2018  01/11/2023
# 3   Mr Lahrie Mohamed  26/10/2018  26/10/2023
# 4   Mr Lahrie Mohamed  26/10/2018  26/10/2023

# %%
len(final_df)
# Out:
# 2332

# %%
# file path of google credentials
filepath_cred = os.path.dirname(os.path.dirname(os.getcwd()))+'/ignore_me/service_account.json'

# use creds to create a client to interact with the Google Drive API
scope = ['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name(filepath_cred, scope)
client = gspread.authorize(creds)

# Find a workbook by name and open the first sheet
# Make sure you use the right name here.
sheet = client.open("hmo_registers").sheet1

# Extract and print all of the values
# list_of_hashes = sheet.get_all_records()
# print(list_of_hashes)
# Out:
# [{'1': 'once ', '2': 'i', '3': 'ate'}, {'1': 'a', '2': 'fish', '3': 'alive'}]

# %%
# final_df.columns.values.tolist()

# %%
# final_df.values.tolist()

# %%
final_df.columns.values.tolist() + final_df.values.tolist()
# Out:
# ['ref_no',
#  'property_address',
#  'licence_holder',
#  'start_date',
#  'end_date',
#  ['14531',
#   '43 Chester Road, Walthamstow, E17 7HP',
#   ' Mr Lahrie Mohamed',
#   '15/03/2018',
#   '15/03/2023'],
#  ['20502',
#   'Flat 1, 8 Goldsmith Road, Leyton, E10 5HA',
#   ' Mr Lahrie Mohamed',
#   '12/05/2017',
#   '12/05/2022'],
#  ['20881',
#   'Flat 2, 79 Park Road, Leyton, E10 7BZ',
#   ' Mr Lahrie Mohamed',
#   '01/11/2018',
#   '01/11/2023'],
#  ['20932',
#   'Ground Floor Flat, 23 Cornwallis Road, Walthamstow, E17 6NL',
#   ' Mr Lahrie Mohamed',
#   '26/10/2018',
#   '26/10/2023'],
#  ['21254',
#   'Flat 3, 62 St James Street, Walthamstow, E17 7PE',
#   ' Mr Lahrie Mohamed',
#   '26/10/2018',
#   '26/10/2023'],
#  ['21484',
#   'Flat 1, 165 Sinclair Road, Chingford, E4 8PP',
#   ' Mr Moshe Newman',
#   '22/06/2016',
#   '22/06/2021'],
#  ['22965',
#   '24 Mayfield Road, Walthamstow, E17 5RH',
#   ' Mr David Mitchell',
#   '04/01/2016',
#   '04/01/2021'],
#  ['24877',
#   'Ground Floor Flat, 174 Blackhorse Lane, Walthamstow, E17 6AA',
#   ' Mr Mohammed Farooq Arif',
#   '05/11/2018',
#   '05/11/2023'],
#  ['25327',
#   'Ground Floor Studio Flat, 110 Markhouse Road, Walthamstow, E17 8BG',
#   ' Mr Mohammed Arif',
#   '13/05/2019',
#   '13/05/2024'],
#  ['25335',
#   'Ground Floor Rear Flat, 110 Markhouse Road, Walthamstow, E17 8BG',
#   ' Mr Mohammed Arif',
#   '18/04/2019',
#   '18/04/2024'],
#  ['25972',
#   '24a Wood Street, Walthamstow, E17 3HT',
#   ' Mr Jasim Irani',
#   '22/02/2016',
#   '22/02/2021'],
#  ['25981',
#   '24b Wood Street, Walthamstow, E17 3HT',
#   ' Mr Jasim Irani',
#   '22/02/2016',
#   '22/02/2021'],
#  ['26207',
#   'Ground Floor Flat, 42 Gainsford Road, Walthamstow, E17 6QB',
#   ' Mr Mohammed Arif',
#   '17/07/2017',
#   '17/07/2022'],
#  ['26211',
#   'Flat 4, 33 Cleveland Park Avenue, Walthamstow, E17 7BP',
#   ' Mr Lahrie Mohamed',
#   '26/10/2018',
#   '26/10/2023'],
#  ['26244',
#   'First Floor Flat, 28 Gainsford Road, Walthamstow, E17 6QB',
#   ' Mr Mohammed Arif',
#   '27/03/2018',
#   '27/03/2023'],
#  ['26274',
#   'Ground Floor Flat, 28 Gainsford Road, Walthamstow, E17 6QB',
#   ' Mr Mohammed Arif',
#   '13/09/2017',
#   '13/09/2022'],
#  ['26347',
#   'Flat A, 642 Lea Bridge Road, Leyton, E10 6AP',
#   ' Mr Lahrie Mohamed',
#   '24/12/2018',
#   '24/12/2023'],
#  ['26352',
#   '642 Lea Bridge Road, Leyton, E10 6AP',
#   ' Mr Lahrie Mohamed',
#   '26/10/2018',
#   '26/10/2023'],
#  [26366,
#   '22a Copeland Road, Walthamstow, E17 9DB',
#   'Mr Mohammed Arif',
#   '05/04/2019',
#   '05/04/2024'],
#  [27236,
#   '101b Markhouse Road, Walthamstow, E17 8DQ',
#   'Mr Mohammed Arshed Arif',
#   '05/04/2019',
#   '05/04/2024'],
#  [27605,
#   'Ground Floor, 262 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '26/02/2018',
#   '26/02/2023'],
#  [28036,
#   '1 Cannock Court, 3 Hawker Place, Walthamstow, E17 4GD',
#   'Mrs Wendy Hoyte',
#   '02/02/2016',
#   '02/02/2021'],
#  [28224,
#   '47 St Andrews Road, Walthamstow, E17 6BB',
#   'Mr Simon Oyeniyi',
#   '27/04/2016',
#   '27/04/2021'],
#  [28228,
#   '100 Palmerston Road, Walthamstow, E17 6PZ',
#   'Mortgage Administration',
#   '25/01/2018',
#   '25/01/2023'],
#  [28245,
#   '240 St Johns Road, Walthamstow, E17 4JN',
#   'Ms Najma Hussain',
#   '04/02/2016',
#   '04/02/2021'],
#  [28338,
#   '101c Markhouse Road, Walthamstow, E17 8DQ',
#   'Mortgage Administration',
#   '12/11/2018',
#   '12/11/2023'],
#  [28345,
#   '17 Howard Road, Walthamstow, E17 4SH',
#   'Rubina Butt',
#   '19/07/2016',
#   '19/07/2021'],
#  [28733,
#   'Flat 1, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '05/03/2018',
#   '05/03/2023'],
#  [28742,
#   'Flat 2, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [28782,
#   'Flat 3, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '19/03/2018',
#   '19/03/2023'],
#  [28790,
#   'Flat 4, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '11/04/2018',
#   '11/04/2023'],
#  [28794,
#   'Flat 5, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '11/04/2018',
#   '11/04/2023'],
#  [28795,
#   'Flat 6, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '11/04/2018',
#   '11/04/2023'],
#  [28805,
#   'Flat 7, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28813,
#   'Flat 8, 266-268 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Asad Chaudhary',
#   '06/03/2018',
#   '06/03/2023'],
#  [28831,
#   'Flat 1, 469-471 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28840,
#   'Flat 2, 469-471 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28849,
#   'Flat 3, 469-471 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '06/03/2018',
#   '06/03/2023'],
#  [28858,
#   'Flat 4, 469-471 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '06/03/2018',
#   '06/03/2023'],
#  [28861,
#   'Flat 5, 469-471 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28865,
#   'Flat 6, 469-471 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '06/03/2018',
#   '06/03/2023'],
#  [28923,
#   'Flat A, 475 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [28932,
#   'Flat B, 475 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28940,
#   'Flat C, 475 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [28963,
#   'Flat D, 475 High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28980,
#   'Flat A, 56 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [28983,
#   'Ground Floor Flat 1, 317 Church Road, Leyton, E10 7JG',
#   'Mr Justin Chilton',
#   '28/06/2016',
#   '28/06/2021'],
#  [29239,
#   'Flat B, 56 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [29243,
#   'Flat C, 56 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '08/03/2018',
#   '08/03/2023'],
#  [29245,
#   'Flat 1, 60 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [29246,
#   'Flat 2, 60 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [29249,
#   'Flat 3, 60 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [29251,
#   'Flat 4, 60 St Mary Road, Walthamstow, E17 9RE',
#   'Mr Asad Chaudhary',
#   '07/03/2018',
#   '07/03/2023'],
#  [29256,
#   '15 Exeter Road, Walthamstow, E17 7QJ',
#   'Mr Asad Chaudhary',
#   '08/03/2018',
#   '08/03/2023'],
#  [29276,
#   'Flat D, 534 High Road Leytonstone, Leytonstone, E11 3EE',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [29278,
#   'Flat 1, 479a High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '09/03/2018',
#   '09/03/2023'],
#  [29279,
#   'Flat 2, 479a High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '04/02/2016',
#   '04/02/2021'],
#  [29280,
#   'Flat 5, 481e High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '04/02/2016',
#   '04/02/2021'],
#  [29281,
#   'Flat 6, 479a High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '09/03/2018',
#   '09/03/2023'],
#  [29282,
#   'Flat 7, 479a High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '09/03/2018',
#   '09/03/2023'],
#  [29297,
#   '21 Holland Court, Evelyn Road, Walthamstow, E17 9HB',
#   'Mrs Quaisra Skipwith',
#   '08/03/2016',
#   '08/03/2021'],
#  [29305,
#   'Flat 3, 479a High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '16/11/2017',
#   '16/11/2022'],
#  [29308,
#   'Flat 4, 481e High Road Leytonstone, Leytonstone, E11 4JU',
#   'Mr Asad Chaudhary',
#   '16/11/2017',
#   '16/11/2022'],
#  [29317,
#   'Flat 1, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [29319,
#   'Flat 2, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '09/03/2018',
#   '09/03/2023'],
#  [29354,
#   'Flat 3, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '16/11/2017',
#   '16/11/2022'],
#  [29367,
#   'Flat 4, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '16/11/2017',
#   '16/11/2022'],
#  [29381,
#   'Flat 5, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [29407,
#   'Flat 6, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [29446,
#   'Flat 7, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '09/03/2018',
#   '09/03/2023'],
#  [29462,
#   'Flat 9, 231-233 Hoe Street, Walthamstow, E17 9PP',
#   'Mr Asad Chaudhary',
#   '22/03/2018',
#   '22/03/2023'],
#  [29555,
#   'Flat 3, 527-529 High Road Leytonstone, Leytonstone, E11 4PB',
#   'Mr Asad Chaudhary',
#   '11/04/2018',
#   '11/04/2023'],
#  [29584,
#   'Flat 6, 527-529 High Road Leytonstone, Leytonstone, E11 4PB',
#   'Mr Asad Chaudhary',
#   '11/04/2018',
#   '11/04/2023'],
#  [29765,
#   'Flat B, 487 High Road Leytonstone, Leytonstone, E11 4PG',
#   'Mr Asad Chaudhary',
#   '12/03/2018',
#   '12/03/2023'],
#  [29944,
#   '72a Maynard Road, Walthamstow, E17 9JF',
#   'Mr Asad Chaudhary',
#   '26/03/2018',
#   '26/03/2023'],
#  [30001,
#   '72b Maynard Road, Walthamstow, E17 9JF',
#   'Mr Asad Chaudhary',
#   '27/06/2018',
#   '27/06/2023'],
#  [30013,
#   '72c Maynard Road, Walthamstow, E17 9JF',
#   'Mr Asad Chaudhary',
#   '11/04/2018',
#   '11/04/2023'],
#  [30074,
#   '44a Markhouse Road, Walthamstow, E17 8BD',
#   'Mrs Balvinder Dhani',
#   '17/06/2016',
#   '17/06/2021'],
#  [30094,
#   '81 Erskine Road, Walthamstow, E17 6SA',
#   'Mr Asad Chaudhary',
#   '08/03/2018',
#   '08/03/2023'],
#  [30249,
#   '46a Markhouse Road, Walthamstow, E17 8BD',
#   'Mrs Balvinder Dhani',
#   '17/06/2016',
#   '17/06/2021'],
#  [30533,
#   '106 South Birkbeck Road, Leytonstone, E11 4JH',
#   ' Mrs Ghazala Jamshaid',
#   '20/09/2016',
#   '20/09/2021'],
#  [30735,
#   '52 Lister Road, Leytonstone, E11 3DS',
#   ' Ms Anna Georghiou',
#   '18/01/2016',
#   '18/01/2021'],
#  [30860,
#   '218a Westward Road, Chingford, E4 8QQ',
#   ' Mr Jaydeep Vansadia',
#   '02/02/2016',
#   '02/02/2021'],
#  [32314,
#   '48a Station Road, Chingford, E4 7BE',
#   ' Mr Mohammad Saeed Akhtar',
#   '05/02/2016',
#   '05/02/2021'],
#  [32355,
#   '34 Overton Road, Leyton, E10 7PR',
#   ' Miss Cynthia Henry',
#   '08/02/2016',
#   '08/02/2024'],
#  [32522,
#   '2 Bittern Court, 44 Connaught Avenue, Chingford, E4 7UF',
#   ' Mr David Smith',
#   '23/03/2016',
#   '23/03/2021'],
#  [32670,
#   '',
#   'Flat 7, Roxwell Studios, Roxwell Trading Park, Argall Avenue, Leyton, E10 L7eQaY Valley Properties Limited',
#   '12/12/2016',
#   '12/12/2021'],
#  [33053,
#   'Flat 9, 12-14 St James Street, Walthamstow, E17 7PF',
#   ' Mrs Bushra Awan',
#   '12/01/2017',
#   '12/01/2022'],
#  [33054,
#   'Flat 7, 12-14 St James Street, Walthamstow, E17 7PF',
#   ' Mrs Bushra Awan',
#   '12/01/2017',
#   '12/01/2022'],
#  [33126,
#   '7 Goodman Road, Leyton, E10 6JG',
#   ' Mr Babar Khadam',
#   '21/03/2016',
#   '21/03/2021'],
#  [33191,
#   '486a Hoe Street, Walthamstow, E17 9AH',
#   ' Mr Ali Hamid',
#   '06/11/2019',
#   '06/11/2024'],
#  [33280,
#   '96 Markhouse Road, Walthamstow, E17 8BG',
#   ' Mr maqbool ahmad',
#   '04/03/2016',
#   '04/03/2021'],
#  [33309,
#   '34 Walpole Road, Walthamstow, E17 6PT',
#   ' Mrs Mary Wickramarathna',
#   '16/03/2016',
#   '16/03/2021'],
#  [33387,
#   'Flat C, 316a High Road Leyton, Leyton, E10 5PW',
#   ' Mr Tashfeen Imtiaz',
#   '25/05/2016',
#   '25/05/2021'],
#  [33398,
#   '16 Horner Court, 3 South Birkbeck Road, Leytonstone, E11 4HY',
#   ' Mr Shah Alam',
#   '07/03/2016',
#   '07/03/2021'],
#  [33422,
#   '11 Fern Court, 121 Higham Station Avenue, Chingford, E4 9XA',
#   ' Mr Tony Berelson',
#   '16/02/2016',
#   '16/02/2021'],
#  [33619,
#   'First Floor Flat 2, 4 The Crescent, Walthamstow, E17 8AB',
#   ' Ms Jasmine Danish',
#   '03/03/2016',
#   '03/03/2021'],
#  [33664,
#   'Flat 1, 22 Clarendon Road, Leytonstone, E11 1DA',
#   ' Mr Jacobus Blomerus',
#   '17/03/2016',
#   '17/03/2021'],
#  [33679,
#   'First Floor Flat 2, 105 Leslie Road, Leytonstone, E11 4HF',
#   ' Mr Henderson Inniss',
#   '21/03/2016',
#   '21/03/2021'],
#  [33742,
#   'First Floor Flat, 390 Forest Road, Walthamstow, E17 5JF',
#   ' Miss Sharon Collins',
#   '29/03/2016',
#   '29/03/2021'],
#  [33772,
#   'First Floor Flat 2, 37 Leyton Park Road, Leyton, E10 5RJ',
#   ' Mr julien Mills',
#   '23/03/2016',
#   '23/03/2021'],
#  [33773,
#   'Ground Floor Flat 1, 4 The Crescent, Walthamstow, E17 8AB',
#   ' Ms Jasmine Danish',
#   '23/03/2016',
#   '23/03/2021'],
#  [33825,
#   'First Floor Flat 2, 64 Calderon Road, Leytonstone, E11 4EU',
#   ' Mrs Smeena Faisel',
#   '14/03/2016',
#   '14/03/2021'],
#  [33940,
#   'Flat 2, 236 High Road Leyton, Leyton, E10 5PS',
#   ' Mr John King',
#   '11/10/2016',
#   '11/10/2021'],
#  [33964,
#   'First Floor Flat 2, 54 Michael Road, Leytonstone, E11 3DY',
#   ' Mr Amrit Pal Singh',
#   '18/02/2016',
#   '18/02/2021'],
#  [33982,
#   'Ground Floor Flat 1, 54 Michael Road, Leytonstone, E11 3DY',
#   ' Mr Amrit Pal Singh',
#   '22/02/2016',
#   '22/02/2021'],
#  [34098,
#   '11 Winchester Court, 242 Billet Road, Walthamstow, E17 5HE',
#   ' Ms MAUREEN ZAWEDDE',
#   '18/05/2016',
#   '18/05/2021'],
#  [34240,
#   '23 Belvedere Road, Leyton, E10 7NW',
#   ' Mr ismail baiyat',
#   '07/04/2016',
#   '07/04/2021'],
#  [34254,
#   '6 Ingrebourne Court, 45 Chingford Avenue, Chingford, E4 6RL',
#   ' Mr SONER KADRI',
#   '04/04/2016',
#   '04/04/2021'],
#  [34321,
#   'Flat D, 230 Forest Road, Walthamstow, E17 6JG',
#   ' Mr Isaac Spitzer',
#   '08/07/2016',
#   '08/07/2021'],
#  [34339,
#   '745b High Road Leytonstone, Leytonstone, E11 4QS',
#   ' Mr Trevor Hollinshead',
#   '14/04/2016',
#   '14/04/2021'],
#  [34356,
#   'Flat B, 230 Forest Road, Walthamstow, E17 6JG',
#   'Mr Isaac Spitzer',
#   '14/03/2017',
#   '14/03/2022'],
#  [34358,
#   'Flat A, 230 Forest Road, Walthamstow, E17 6JG',
#   'Mr Isaac Spitzer',
#   '08/07/2016',
#   '08/07/2021'],
#  [34360,
#   'Flat C, 230 Forest Road, Walthamstow, E17 6JG',
#   'Mr Isaac Spitzer',
#   '03/01/2019',
#   '03/01/2024'],
#  [34393,
#   '37a West End Avenue, Leyton, E10 6DY',
#   'Mr Chris Byrne',
#   '11/05/2016',
#   '11/05/2021'],
#  [34472,
#   '2 Argyle Road, Stratford, E15 1UJ',
#   'Mr Pengcheng Feng',
#   '16/06/2016',
#   '16/06/2021'],
#  [34500,
#   '319 Billet Road, Walthamstow, E17 5PX',
#   'Mr Alireza Mardani Nejad',
#   '24/03/2016',
#   '24/03/2021'],
#  [34517,
#   '21a Fleeming Road, Walthamstow, E17 5ET',
#   'Mr Kamaljit Clare',
#   '24/03/2016',
#   '24/03/2021'],
#  [34658,
#   'Ground Floor Flat 1, 35 Hatherley Road, Walthamstow, E17 6SE',
#   'Mrs Christina Camargo Lima',
#   '11/05/2016',
#   '11/05/2021'],
#  [34753,
#   'Ground Floor Flat, 98 Markhouse Road, Walthamstow, E17 8BG',
#   'Mr maqbool ahmad',
#   '13/02/2017',
#   '13/02/2022'],
#  [34754,
#   'Flat 2, 55-57 Hainault Road, Leytonstone, E11 1EA',
#   'Mr Natwest huang',
#   '03/02/2017',
#   '03/02/2022'],
#  [34757,
#   'Flat 5, 55-57 Hainault Road, Leytonstone, E11 1EA',
#   'Mr zhonghua huang',
#   '18/01/2018',
#   '18/01/2023'],
#  [34780,
#   'Ground Floor Flat, 32 Somers Road, Walthamstow, E17 6RX',
#   'Mr Stephen Beecham',
#   '16/02/2017',
#   '16/02/2022'],
#  [34929,
#   '702a High Road Leyton, Leyton, E10 6JP',
#   'Mr Mabrouk Alloune',
#   '01/12/2016',
#   '01/12/2021'],
#  [35269,
#   '7 Brook Court, 2 Green Pond Road, Walthamstow, E17 6EB',
#   'Mr Alireza Mardani Nejad',
#   '27/05/2016',
#   '27/05/2021'],
#  [35368,
#   '309, 6 Church Hill, Walthamstow, E17 3AG',
#   'Mrs Susanna Rogers',
#   '31/01/2017',
#   '31/01/2022'],
#  [35369,
#   '37 Top House Rise, Chingford, E4 7EE',
#   'Mrs Kathryn Protsiv',
#   '25/05/2016',
#   '25/05/2021'],
#  [35373,
#   '83 Pembroke Road, Walthamstow, E17 9BB',
#   'Mrs Fara Akbar',
#   '10/05/2016',
#   '10/05/2021'],
#  [35439,
#   '93 Harrow Road, Leytonstone, E11 3PS',
#   'Mr Milko Nedyalkov',
#   '10/05/2016',
#   '10/05/2021'],
#  [35476,
#   '304, 6 Church Hill, Walthamstow, E17 3AG',
#   'Miss Lee Bagnald',
#   '31/01/2017',
#   '31/01/2022'],
#  [35496,
#   '5 Oakdale Gardens, Chingford, E4 9HA',
#   'Mr Rashed Hussain',
#   '14/07/2016',
#   '14/07/2021'],
#  [35629,
#   '25 Bulwer Court, Bulwer Court Road, Leytonstone, E11 1DB',
#   'Mr majid ishaq',
#   '14/09/2016',
#   '14/09/2021'],
#  [35894,
#   '92 Kettlebaston Road, Leyton, E10 7PF',
#   'Mrs Hyacinth Craigie',
#   '01/07/2016',
#   '01/07/2021'],
#  [35965,
#   '31b First Avenue, Walthamstow, E17 9QG',
#   'Mr John Hill',
#   '27/06/2016',
#   '27/06/2021'],
#  [35974,
#   '8 Morieux Road, Leyton, E10 7LL',
#   'Ms Dione Rayside',
#   '11/07/2016',
#   '11/07/2021'],
#  [36121,
#   '91 Claude Road, Leyton, E10 6NF',
#   'Mr Daniel McAllister',
#   '25/07/2016',
#   '25/07/2021'],
#  [36150,
#   'Ground Floor Flat 1, 7 Belgrave Road, Leyton, E10 6LD',
#   'Mr Saqib Hussain',
#   '10/06/2016',
#   '10/06/2021'],
#  [36154,
#   'First Floor Flat 2, 7 Belgrave Road, Leyton, E10 6LD',
#   'Mr Saqib Hussain',
#   '10/06/2016',
#   '10/06/2021'],
#  [36165,
#   '69 York Road, Walthamstow, E17 7HU',
#   "Mr Kevin O'Connor",
#   '21/06/2016',
#   '21/06/2021'],
#  [36204,
#   '23 Beaconsfield Road, Leyton, E10 5RD',
#   'Mr Tariq Mahmood',
#   '03/04/2018',
#   '03/04/2023'],
#  [36276,
#   '87 Chelmsford Road, Walthamstow, E17 8NP',
#   'Christopher Scheuer',
#   '17/06/2016',
#   '17/06/2021'],
#  [36300,
#   '2 Marion Grove, Woodford Green, IG8 9TA',
#   'Mrs Linda Bracey',
#   '21/06/2016',
#   '21/06/2021'],
#  [36302,
#   '21 Bedgebury Court, 1 Hawker Place, Walthamstow, E17 4GA',
#   'Mr Miguel Francisco',
#   '27/06/2016',
#   '27/06/2021'],
#  [36313,
#   'First Floor Flat B, 102 South Birkbeck Road, Leytonstone, E11 4JH',
#   'Mr Primeview Developments Limited',
#   '09/02/2017',
#   '09/02/2022'],
#  [36316,
#   'Basement Flat C, 102 South Birkbeck Road, Leytonstone, E11 4JH',
#   'Mr Primeview Developments Limited Limited',
#   '09/02/2017',
#   '09/02/2022'],
#  [36318,
#   'First Floor Flat E, 102 South Birkbeck Road, Leytonstone, E11 4JH',
#   'Mr Primeview Developments Limited',
#   '09/02/2017',
#   '09/02/2022'],
#  [36320,
#   'Ground Floor Flat F, 102 South Birkbeck Road, Leytonstone, E11 4JH',
#   'Mr Primeview Developments Limited',
#   '09/02/2017',
#   '09/02/2022'],
#  [36322,
#   'First Floor Flat G, 102 South Birkbeck Road, Leytonstone, E11 4JH',
#   'Mr Primeview Developments Limited',
#   '10/02/2017',
#   '10/02/2022'],
#  [36434,
#   '1 Beech Tree Glade, Chingford, E4 6BG',
#   'Mr chetan natha',
#   '29/06/2016',
#   '29/06/2021'],
#  [36455,
#   'Flat 5, 17 Alexandra Road, Leyton, E10 5QQ',
#   'Mr Alex George',
#   '18/03/2020',
#   '18/03/2021'],
#  [36461,
#   'Flat 6, 17 Alexandra Road, Leyton, E10 5QQ',
#   'Mr Alex George',
#   '13/02/2020',
#   '13/02/2021'],
#  [36551,
#   '158a Wallwood Road, Leytonstone, E11 1AN',
#   'Mr Dipak Naran',
#   '12/07/2016',
#   '12/07/2021'],
#  [36615,
#   '204a Lea Bridge Road, Leyton, E10 7LN',
#   'Ms FATEMEH AMIDI',
#   '14/10/2016',
#   '14/10/2021'],
#  [36617,
#   'Flat 3, 77 Leslie Road, Leytonstone, E11 4HF',
#   'Mr kasim ahmad',
#   '31/10/2018',
#   '31/10/2023'],
#  [36785,
#   'First Floor Flat, 34 Buckland Road, Leyton, E10 6QS',
#   'Mr Andrea Mondelci',
#   '21/07/2016',
#   '21/07/2021'],
#  [36947,
#   '34 Churchbank, 1 Teresa Mews, Walthamstow, E17 3BE',
#   'Mr Simon Proctor',
#   '29/07/2016',
#   '29/07/2021'],
#  [37174,
#   '72 Clarence Road, Walthamstow, E17 6AQ',
#   'Mr Tom Woolford',
#   '09/08/2016',
#   '09/08/2021'],
#  [37241,
#   '28 Albert Avenue, Chingford, E4 8LG',
#   'Miss Jolanta Kunecka',
#   '29/06/2016',
#   '29/06/2021'],
#  [37272,
#   '16 Russets Close, Chingford, E4 6UA',
#   'Miss Keris McNaught',
#   '13/12/2016',
#   '31/12/2021'],
#  [37285,
#   '1 Oaks Court, 226-228 Cann Hall Road, Leytonstone, E11 3NF',
#   'Mr stuart lawson',
#   '14/02/2017',
#   '14/02/2022'],
#  [37308,
#   '8 Green Pond Close, Walthamstow, E17 6EE',
#   'Miss Susan Lee',
#   '29/11/2016',
#   '29/11/2021'],
#  [37422,
#   'Ground Floor Flat 1, 44 Nottingham Road, Leyton, E10 6EP',
#   'Mrs NOORJEHAN KALSHEKER',
#   '14/09/2016',
#   '14/09/2021'],
#  [37423,
#   'First Floor Flat 2, 44 Nottingham Road, Leyton, E10 6EP',
#   'Mrs NOORJEHAN KALSHEKER',
#   '14/09/2016',
#   '14/09/2021'],
#  [37513,
#   '188a Chingford Mount Road, Chingford, E4 9BS',
#   'Ms Gillian Hand',
#   '20/10/2016',
#   '20/10/2021'],
#  [37519,
#   '65 Vansittart Road, Forest Gate, E7 0AT',
#   'Ms ADEPEJU BADARU',
#   '05/09/2016',
#   '05/09/2021'],
#  [37546,
#   '46 Devonshire Close, Stratford, E15 1UG',
#   'Mr Gerry McNulty',
#   '27/07/2016',
#   '27/07/2021'],
#  [37552,
#   '4 Acorn Lodge, 21 Fulready Road, Leyton, E10 6ED',
#   'Mr Priyesh Krishnapillai',
#   '31/08/2016',
#   '31/08/2021'],
#  [37562,
#   'First Floor Flat 2, 30 Lea Hall Road, Leyton, E10 7AN',
#   'Miss Asmita Rawal Guntermann',
#   '22/09/2016',
#   '22/09/2021'],
#  [37600,
#   '2b West End Avenue, Leyton, E10 6DZ',
#   'Mr Alec Dick',
#   '16/08/2016',
#   '16/08/2021'],
#  [37668,
#   '83 Essex Road, Leyton, E10 6EG',
#   'Mr Nagendran Subendran',
#   '02/09/2016',
#   '02/09/2021'],
#  [37674,
#   '42 Woodlands Road, Walthamstow, E17 3LE',
#   'Mrs Pamela Jones',
#   '01/09/2016',
#   '01/09/2021'],
#  [37727,
#   'Ground Floor Side Flat, 121 Abbotts Park Road, Leyton, E10 6HU',
#   'Mr Pervez Latif',
#   '11/01/2017',
#   '11/01/2022'],
#  [37728,
#   'Ground Floor Flat, 121 Abbotts Park Road, Leyton, E10 6HU',
#   'Mr Pervez Latif',
#   '11/01/2017',
#   '11/01/2022'],
#  [37729,
#   'First Floor Flat, 121 Abbotts Park Road, Leyton, E10 6HU',
#   'Mr Pervez Latif',
#   '11/01/2017',
#   '11/01/2022'],
#  [37730,
#   'Flat 2, 11 Percy Road, Leytonstone, E11 1AJ',
#   'Mrs Stanimira Ribarova',
#   '23/08/2016',
#   '23/08/2021'],
#  [37735,
#   '22 Caley Court, 12 Erskine Road, Walthamstow, E17 6GB',
#   'Mr Andre Henry',
#   '31/08/2016',
#   '31/08/2021'],
#  [37743,
#   'Flat C, 39 Addison Road, Walthamstow, E17 9LS',
#   'Ms YukLing Lai',
#   '25/08/2016',
#   '25/08/2021'],
#  [37804,
#   'Flat 2, 158 Coppermill Lane, Walthamstow, E17 7HE',
#   'Miss Yvette Watson',
#   '04/11/2016',
#   '04/11/2021'],
#  [37887,
#   '34 Bateman Road, Chingford, E4 8ND',
#   'Mrs monica johnson',
#   '06/09/2016',
#   '06/09/2021'],
#  [37950,
#   '44 Trumpington Road, Forest Gate, E7 9EJ',
#   'Mr Idris Patel',
#   '12/01/2017',
#   '12/01/2022'],
#  [38016,
#   '8a West Avenue Road, Walthamstow, E17 9SE',
#   'Mrs Eleanor Bradshaw',
#   '10/10/2016',
#   '10/10/2021'],
#  [38021,
#   '27 Ruckholt Close, Leyton, E10 5NX',
#   'Mrs Samera Hussain',
#   '01/06/2017',
#   '01/06/2022'],
#  [38067,
#   '6 Forest Court, Leytonstone, E11 1PL',
#   'Mr James Carmody',
#   '02/11/2016',
#   '02/11/2021'],
#  [38090,
#   '5 Aston Grove Hotel, 112 Grove Road, Walthamstow, E17 9BY',
#   'Mrs Natasa Craighead',
#   '20/10/2016',
#   '20/10/2021'],
#  [38186,
#   '325a Lea Bridge Road, Leyton, E10 7LA',
#   'Mr Ali Erdogan',
#   '13/09/2016',
#   '13/09/2021'],
#  [38221,
#   '2 Garamond House, 181 Grove Road, Walthamstow, E17 9BZ',
#   'Ms Yvonne Dove',
#   '03/11/2016',
#   '03/11/2021'],
#  [38225,
#   '123 Farnan Avenue, Walthamstow, E17 4NH',
#   'Ms Asha Thomas',
#   '05/10/2016',
#   '05/10/2021'],
#  [38257,
#   '12 Hawthorne Court, 117 Higham Station Avenue, Chingford, E4 9UY',
#   'Mr Christopher Christou',
#   '11/10/2016',
#   '11/10/2021'],
#  [38259,
#   'Flat 5, 1 Connaught Avenue, Chingford, E4 7AE',
#   'Mr John Devereux',
#   '15/03/2017',
#   '15/03/2022'],
#  [38261,
#   'Flat 3, 1 Connaught Avenue, Chingford, E4 7AE',
#   'Mr John Devereux',
#   '15/03/2017',
#   '15/03/2022'],
#  [38265,
#   '95b Warren Road, Leyton, E10 5PZ',
#   'Mr Andrew Whittaker',
#   '30/11/2016',
#   '30/11/2021'],
#  [38373,
#   '35a Addison Road, Walthamstow, E17 9LS',
#   'Paul McCarthy',
#   '06/01/2017',
#   '06/01/2022'],
#  [38377,
#   '8 Maynard Road, Walthamstow, E17 9JG',
#   'Mrs Dhun Prior',
#   '11/10/2016',
#   '11/10/2021'],
#  [38399,
#   '81a Ramsay Road, Forest Gate, E7 9EN',
#   'Mrs Musarrat Shabbir',
#   '07/07/2017',
#   '07/07/2022'],
#  [38422,
#   '187 Wadham Road, Walthamstow, E17 4HU',
#   'Mr Zuber Majid',
#   '08/02/2017',
#   '08/02/2022'],
#  [38491,
#   '65 King Edward Road, Walthamstow, E17 6HY',
#   'Mr James Hamilton',
#   '03/11/2016',
#   '03/11/2021'],
#  [38496,
#   '121 Blenheim Road, Walthamstow, E17 6HT',
#   'Mrs Amelia Hall',
#   '08/11/2016',
#   '08/11/2021'],
#  [38503,
#   '57 Church Lane, Walthamstow, E17 9RN',
#   'Mrs Christine Mary Thakur',
#   '25/10/2016',
#   '25/10/2021'],
#  [38507,
#   '46 Brookdale Road, Walthamstow, E17 6QL',
#   'Mr Graham Howarth',
#   '19/10/2016',
#   '19/10/2021'],
#  [38634,
#   '60 Luton Road, Walthamstow, E17 5LN',
#   'Mrs Maria Cioplea',
#   '25/11/2016',
#   '25/11/2021'],
#  [38695,
#   '592b High Road Leytonstone, Leytonstone, E11 3DA',
#   'Mr Graham Sutton',
#   '02/11/2016',
#   '02/11/2021'],
#  [38704,
#   '21 Grange Park Road, Leyton, E10 5EP',
#   'Mr Jewels Uddin',
#   '13/10/2016',
#   '13/10/2021'],
#  [38855,
#   'First Floor Flat 2, 29 Browns Road, Walthamstow, E17 4RN',
#   'Miss Brigitte Castillion',
#   '18/01/2017',
#   '18/01/2022'],
#  [38856,
#   '64 Lansdowne Road, Walthamstow, E17 8QU',
#   'Mr Amjad Rehman',
#   '19/01/2017',
#   '19/01/2022'],
#  [38883,
#   '89 Newport Road, Leyton, E10 6PH',
#   'Mr Santander Nasri',
#   '02/12/2016',
#   '02/12/2021'],
#  [38923,
#   'Flat 2, 30a Forest View, Chingford, E4 7AU',
#   'Mrs Jennifer Dunk',
#   '15/03/2017',
#   '15/03/2022'],
#  [38999,
#   'Flat 4, 154 Coppermill Lane, Walthamstow, E17 7HE',
#   'Ms Helen Fontaine',
#   '18/08/2017',
#   '18/08/2022'],
#  [39009,
#   '168 Albert Road, Leyton, E10 6PB',
#   'Mrs Eileen Hannan',
#   '05/12/2016',
#   '05/12/2021'],
#  [39039,
#   '31 Newport Road, Leyton, E10 6PH',
#   'Ms ICELYN DAVIS',
#   '17/02/2017',
#   '17/02/2022'],
#  [39049,
#   '24 Whitney Road, Leyton, E10 7HG',
#   'Mrs Fatima Rahman',
#   '07/04/2017',
#   '07/04/2022'],
#  [39052,
#   '43a Erskine Road, Walthamstow, E17 6RZ',
#   'Mr Ejaz Rashid',
#   '29/11/2016',
#   '29/11/2021'],
#  [39054,
#   '350 Markhouse Road, Walthamstow, E17 8EF',
#   'Mr Ejaz Rashid',
#   '04/01/2017',
#   '04/01/2022'],
#  [39060,
#   '16 Manor Court, 80 Beresford Road, Chingford, E4 6EP',
#   'Miss Lauren Wright',
#   '05/01/2017',
#   '05/01/2022'],
#  [39068,
#   'Flat 2, 5 Rochdale Road, Walthamstow, E17 8JF',
#   'Mr Michael Tyrrell',
#   '07/12/2016',
#   '07/12/2021'],
#  [39107,
#   '36 Cranbourne Road, Stratford, E15 2DB',
#   'Ms Sharon Christy',
#   '18/11/2016',
#   '18/11/2021'],
#  [39159,
#   'First Floor Flat, 94 High Road Leyton, Stratford, E15 2BP',
#   'Mr Fares Fawz',
#   '01/02/2017',
#   '01/02/2022'],
#  [39164,
#   '112 Albert Road, Leyton, E10 6PB',
#   'Ms Safak Ustundag',
#   '09/03/2017',
#   '09/03/2022'],
#  [39183,
#   'fff, 83 Bulwer Road, Leytonstone, E11 1BY',
#   'Mr Michael Greene',
#   '26/06/2019',
#   '26/06/2024'],
#  [39191,
#   '38 Rochdale Road, Walthamstow, E17 8JF',
#   'Mr Aderibigbe Adesola',
#   '18/01/2017',
#   '18/01/2022'],
#  [39198,
#   '45 Rookery Court, 80 Ruckholt Road, Leyton, E10 5FA',
#   'Miss Zhen Wu',
#   '18/08/2017',
#   '18/08/2022'],
#  [39202,
#   '139 Chelmsford Road, Walthamstow, E17 8NP',
#   'Mr Lahrie Mohamed',
#   '27/04/2017',
#   '27/04/2022'],
#  [39207,
#   '24 Newport Road, Leyton, E10 6PJ',
#   'Ms Florence Puddifoot',
#   '06/01/2017',
#   '06/01/2022'],
#  [39226,
#   '28 Quant Building, 6 Church Hill, Walthamstow, E17 3AG',
#   'Mr Hugo Owen',
#   '07/03/2017',
#   '07/03/2022'],
#  [39227,
#   '33 Quant Building, 6 Church Hill, Walthamstow, E17 3AG',
#   'Mr Christopher Wilkins',
#   '27/01/2017',
#   '27/01/2022'],
#  [39234,
#   'Ground Floor Flat 73 Hatherley Road, Walthamstow, E17 6SB',
#   'Mr John Magson',
#   '30/05/2017',
#   '30/05/2022'],
#  [39244,
#   '105 Seymour Road, Leyton, E10 7LZ',
#   'Mrs Michelle Goldstein',
#   '06/02/2017',
#   '06/02/2022'],
#  [39246,
#   '41 Melbourne Road, Leyton, E10 7HF',
#   'Mrs Adebisi Mohammed',
#   '20/01/2017',
#   '20/01/2022'],
#  [39313,
#   'Flat 2, 77 Leslie Road, Leytonstone, E11 4HF',
#   'Ms Juana Bacaicoa',
#   '13/12/2016',
#   '13/12/2021'],
#  [39326,
#   '79b St Johns Road, Walthamstow, E17 4JH',
#   'Mr Richard Peltier',
#   '12/01/2017',
#   '12/01/2022'],
#  [39328,
#   '35 Shakespeare Road, Walthamstow, E17 6AS',
#   'Mrs Janice Phanides',
#   '21/12/2016',
#   '21/12/2021'],
#  [39357,
#   '268 Brettenham Road, Walthamstow, E17 5AY',
#   'Mrs Kamal Clare',
#   '21/12/2016',
#   '21/12/2021'],
#  [39386,
#   '7 Camellia Court, The Oaks, Woodford Green, IG8 9NQ',
#   'Miss Mabel Saw',
#   '22/12/2016',
#   '22/12/2021'],
#  [39391,
#   '75a Devonshire Road, Walthamstow, E17 8QH',
#   'Veena Bahl',
#   '29/11/2016',
#   '29/11/2021'],
#  [39416,
#   '75b Devonshire Road, Walthamstow, E17 8QH',
#   'Veena Bahl',
#   '13/02/2017',
#   '13/02/2022'],
#  [39418,
#   '55b Tower Hamlets Road, Walthamstow, E17 4RQ',
#   'Mr guidong zheng',
#   '04/01/2017',
#   '04/01/2022'],
#  [39428,
#   '15 West Court, 28 Church Hill, Walthamstow, E17 9SG',
#   'Mr guidong zheng',
#   '12/12/2016',
#   '12/12/2021'],
#  [39470,
#   '16 Hadleigh Court, 4 Crescent Road, Chingford, E4 6AX',
#   'Mr gerard mcnulty',
#   '27/01/2017',
#   '27/01/2022'],
#  [39497,
#   '55a Cairo Road, Walthamstow, E17 3BB',
#   'Mr Kwok-Sing To',
#   '31/01/2017',
#   '31/01/2022'],
#  [39498,
#   '1 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '05/01/2017',
#   '05/01/2022'],
#  [39500,
#   '2 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '05/01/2017',
#   '05/01/2022'],
#  [39501,
#   '3 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '05/01/2017',
#   '05/01/2022'],
#  [39509,
#   '4 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '24/01/2017',
#   '24/01/2022'],
#  [39510,
#   '5 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '24/01/2017',
#   '24/01/2022'],
#  [39571,
#   '95 Howard Road, Walthamstow, E17 4SG',
#   'Mr Mustafa Jivanjee',
#   '14/06/2017',
#   '14/06/2022'],
#  [39588,
#   '6 Park Road, Walthamstow, E17 7QF',
#   'Mr Shahnawaz Bhayat',
#   '10/01/2017',
#   '10/01/2022'],
#  [39597,
#   '22 Claypole Court, 3 Yunus Khan Close, Walthamstow, E17 8XF',
#   'Mr Paul Turner',
#   '05/01/2017',
#   '05/01/2022'],
#  [39613,
#   '79 Wellesley Road, Walthamstow, E17 8QX',
#   'Mr Ronald Lam',
#   '16/02/2017',
#   '16/02/2022'],
#  [39622,
#   'First Floor Flat, 24a Ivy Road, Walthamstow, E17 8HX',
#   'Ms Halima Iqbal',
#   '04/01/2017',
#   '04/01/2022'],
#  [39629,
#   '8 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '24/01/2017',
#   '24/01/2022'],
#  [39630,
#   '9 Sheila Court, 15 Cranbrook Mews, Walthamstow, E17 7FA',
#   'Mr ANDREW LIPTON',
#   '24/01/2017',
#   '24/01/2022'],
#  [39631,
#   '67 Marmion Close, Chingford, E4 8EN',
#   'Mr Ocal Korkmaz',
#   '04/01/2017',
#   '04/01/2022'],
#  [39705,
#   'Ground Floor Flat 1, 22 Milton Road, Walthamstow, E17 4SR',
#   "Mrs Mary O'Sullivan",
#   '17/01/2017',
#   '17/01/2022'],
#  [39723,
#   '265 Chingford Road, Walthamstow, E17 5AB',
#   'Mr Raheem Iqbal',
#   '30/10/2019',
#   '30/10/2024'],
#  [39756,
#   'Flat A, 2 Lyndhurst Drive, Leyton, E10 6JD',
#   'Mrs Kim Stanislas-Regisford',
#   '31/01/2017',
#   '31/01/2022'],
#  [39790,
#   '592a High Road Leytonstone, Leytonstone, E11 3DA',
#   'Mr Graham Sutton',
#   '16/02/2017',
#   '16/02/2022'],
#  [39803,
#   '37 Elsham Road, Leytonstone, E11 3JH',
#   'Mr Faisal Mahmood',
#   '09/03/2017',
#   '09/03/2022'],
#  [39816,
#   '9 Leyspring Road, Leytonstone, E11 3BP',
#   'Mr Waseem Ahmad',
#   '02/02/2017',
#   '02/02/2022'],
#  [39823,
#   '26 Nathaniel Court, 2 Luther King Close, Walthamstow, E17 8RT',
#   'Mr Alireza Mardani Nejad',
#   '27/01/2017',
#   '27/01/2022'],
#  [39831,
#   '35, 6 Church Hill, Walthamstow, E17 3AG',
#   'Miss ASHA LALIT',
#   '26/01/2017',
#   '26/01/2022'],
#  [39835,
#   '71 Hainault Road, Leytonstone, E11 1DZ',
#   'Mr Steve Bearfield',
#   '26/01/2017',
#   '26/01/2022'],
#  [39838,
#   '99a Billet Road, Walthamstow, E17 5DP',
#   'Mr PAUL WOODS',
#   '25/01/2017',
#   '25/01/2022'],
#  [39854,
#   '24 Litchfield Court, 2 Gandhi Close, Walthamstow, E17 8LN',
#   'Ms Amanda Sanders',
#   '24/01/2017',
#   '24/01/2022'],
#  [39860,
#   '31 Radbourne Crescent, Walthamstow, E17 3RR',
#   'Mr Henry Abban',
#   '24/01/2017',
#   '24/01/2022'],
#  [39890,
#   '21 Onra Road, Walthamstow, E17 8JD',
#   'Ms Tahira Azim',
#   '20/01/2017',
#   '20/01/2022'],
#  [39897,
#   'Ground Floor Flat 1, 29 Lyttelton Road, Leyton, E10 5NQ',
#   'Ms Geeandeo Sooreedoo',
#   '17/10/2017',
#   '17/10/2022'],
#  [39906,
#   '59 Coleridge Road, Walthamstow, E17 6QX',
#   'Mr Lew Brady',
#   '19/01/2017',
#   '19/01/2022'],
#  [39915,
#   '12 Ash Court, 29-30 Forest View, Chingford, E4 7AR',
#   'Miss sarah haley',
#   '19/01/2017',
#   '19/01/2022'],
#  [39952,
#   '32 Thorpe Crescent, Walthamstow, E17 5BY',
#   'Mrs ANNE TREACY',
#   '25/01/2017',
#   '25/01/2022'],
#  [39954,
#   '20 Keith Road, Walthamstow, E17 5BX',
#   'Miss Zoe Walcott',
#   '25/01/2017',
#   '25/01/2022'],
#  [39958,
#   '13 Willow Court, 34 Trinity Close, Leytonstone, E11 4RU',
#   'Mr BERNARD WINEHOUSE',
#   '25/01/2017',
#   '25/01/2022'],
#  [39962,
#   'First Floor Flat 2, 35 Hatherley Road, Walthamstow, E17 6SE',
#   'Mr Lahrie Mohamed',
#   '25/01/2017',
#   '25/01/2022'],
#  [39972,
#   'First Floor Flat 2, 96 Pearcroft Road, Leytonstone, E11 4DR',
#   'Mr Andrew Director',
#   '27/02/2017',
#   '27/02/2022'],
#  [39991,
#   '40 Quant Building, 6 Church Hill, E17 3AG',
#   'Mr Shervin Shameli',
#   '27/06/2017',
#   '27/06/2022'],
#  [39992,
#   '41 Quant Building, 6 Church Hill, E17 3AG',
#   'Mr Yue Gao',
#   '27/06/2017',
#   '27/06/2022'],
#  [39994,
#   '113 Gloucester Road, Walthamstow, E17 6AF',
#   'dekey dolma',
#   '18/07/2017',
#   '18/07/2022'],
#  [40018,
#   '90b Trumpington Road, Forest Gate, E7 9EQ',
#   'Mr Hady Laba',
#   '02/02/2017',
#   '02/02/2022'],
#  [40022,
#   '197 Chingford Road, Walthamstow, E17 5AB',
#   'Mr Mahmood Hussain',
#   '02/02/2017',
#   '02/02/2022'],
#  [40025,
#   '279 Lea Bridge Road, Leyton, E10 7NE',
#   'Miss Veena Bahl',
#   '02/02/2017',
#   '02/02/2022'],
#  [40057,
#   '6 East Point, 90 Church Road, Leyton, E10 5JP',
#   'Ms Eve Kay-Kreizman',
#   '09/02/2017',
#   '09/02/2022'],
#  [40070,
#   '77 St Mary Road, Walthamstow, E17 9RF',
#   'Mr Mohammad Malik',
#   '25/01/2017',
#   '25/01/2022'],
#  [40071,
#   '1b Mayville Road, Leytonstone, E11 4QH',
#   'Mrs Gulten Hayrettin',
#   '07/07/2017',
#   '07/07/2022'],
#  [40089,
#   '19 Belmont Park Road, Leyton, E10 6AU',
#   'Mr Hasan Younis',
#   '30/05/2017',
#   '30/05/2022'],
#  [40092,
#   'Basement Flat D, 102 South Birkbeck Road, Leytonstone, E11 4JH',
#   'Primeview Developments Limited',
#   '31/05/2017',
#   '31/05/2022'],
#  [40113,
#   '6 Summerose Court, 318a Higham Hill Road, Walthamstow, E17 5RG',
#   'Mr Robert Richier',
#   '14/02/2017',
#   '14/02/2022'],
#  [40114,
#   '39, 6 Church Hill, Walthamstow, E17 3AG',
#   'Mr Omar Pervez',
#   '16/03/2017',
#   '16/03/2022'],
#  [40120,
#   '1 Summerose Court, 318a Higham Hill Road, Walthamstow, E17 5RG',
#   'Mr Rob Richier',
#   '14/02/2017',
#   '31/03/2022'],
#  [40122,
#   '2 Summerose Court, 318a Higham Hill Road, Walthamstow, E17 5RG',
#   'Mr Rob Richier',
#   '14/02/2017',
#   '14/02/2022'],
#  [40137,
#   '142 Richmond Road, Leytonstone, E11 4BS',
#   'Mr Antoine Korbendau',
#   '23/02/2017',
#   '23/02/2022'],
#  [40140,
#   'First Floor Flat, 607 Forest Road, Walthamstow, E17 4PP',
#   'Ms s sutton',
#   '23/02/2017',
#   '23/02/2022'],
#  [40147,
#   '118 Marmion Avenue, Chingford, E4 8EH',
#   'Miss Forum Mehta',
#   '14/03/2017',
#   '14/03/2022'],
#  [40152,
#   '98b Markhouse Road, Walthamstow, E17 8BG',
#   'Mr maqbool ahmad',
#   '15/02/2017',
#   '15/02/2022'],
#  [40199,
#   '15 Browning Road, Leytonstone, E11 3AR',
#   'Mrs Katharine Attenborough',
#   '13/02/2017',
#   '13/02/2022'],
#  [40228,
#   '99 Peterborough Road, Leyton, E10 6EL',
#   'Miss Merrin Playle',
#   '13/03/2017',
#   '13/03/2022'],
#  [40255,
#   '20 Avril Way, Chingford, E4 9HS',
#   'Mr Musa Ozen',
#   '14/03/2017',
#   '14/03/2022'],
#  [40258,
#   '9 Aubrey Road, Walthamstow, E17 4SL',
#   'Miss Julie Donaghey',
#   '23/02/2017',
#   '23/02/2022'],
#  [40275,
#   '6 Seton Court, 57 Fairlop Road, Leytonstone, E11 1BQ',
#   'Mr Afzal Shakil',
#   '21/02/2017',
#   '21/02/2022'],
#  [40296,
#   '1a East Avenue, Walthamstow, E17 9NG',
#   'Mr Andrew Woods',
#   '07/03/2017',
#   '07/03/2022'],
#  [40307,
#   'First Floor Flat, 628a Lea Bridge Road, Leyton, E10 6AP',
#   'Mr Jack Goode',
#   '07/04/2017',
#   '07/04/2022'],
#  [40366,
#   '64 Maple Avenue, Chingford, E4 8RR',
#   'Mr Charles Gisanrin',
#   '29/03/2017',
#   '29/03/2022'],
#  [40386,
#   '18 Mark Avenue, Chingford, E4 7NR',
#   'Mr Patrick Kane',
#   '29/03/2017',
#   '29/03/2022'],
#  [40413,
#   '34 Grove Road, Walthamstow, E17 9BN',
#   'Mr Sultan Syed Azfar Husain',
#   '08/03/2017',
#   '08/03/2022'],
#  [40422,
#   'Flat 1, 11b Church Path, Walthamstow, E17 9RQ',
#   'Mr Ben Thomas',
#   '15/03/2017',
#   '15/03/2022'],
#  [40424,
#   'First Floor Flat 2, 40 Northcote Road, Walthamstow, E17 7DU',
#   'Mr Mohammed Arif',
#   '31/10/2017',
#   '31/10/2022'],
#  [40432,
#   '109 Badlis Road, Walthamstow, E17 5LG',
#   'Mr Zuber Majid',
#   '09/03/2017',
#   '09/03/2022'],
#  [40433,
#   '23 Wetherden Street, Walthamstow, E17 8EH',
#   'Mr Zuber Majid',
#   '09/03/2017',
#   '09/03/2022'],
#  [40434,
#   '66 Aubrey Road, Walthamstow, E17 4SL',
#   'Mr Zuber Majid',
#   '13/03/2017',
#   '13/03/2022'],
#  [40435,
#   '39 Belgrave Road, Leyton, E10 6LD',
#   'Mr Zuber Majid',
#   '09/03/2017',
#   '09/03/2022'],
#  [40437,
#   '54 Somerset Road, Walthamstow, E17 8QW',
#   'Mr Zuber Majid',
#   '13/03/2017',
#   '13/03/2022'],
#  [40439,
#   '12 Northbank Road, Walthamstow, E17 4JZ',
#   'Mr Zuber Majid',
#   '10/03/2017',
#   '10/03/2022'],
#  [40441,
#   '68a Northbank Road, Walthamstow, E17 4JZ',
#   'Mr Zuber Majid',
#   '23/05/2017',
#   '23/05/2022'],
#  [40442,
#   '33 Garner Road, Walthamstow, E17 4HE',
#   'Mr Zuber Majid',
#   '10/03/2017',
#   '10/03/2022'],
#  [40455,
#   '101a Chingford Avenue, Chingford, E4 6RG',
#   'Mr Neville Asphall',
#   '02/06/2017',
#   '02/06/2022'],
#  [40457,
#   '50 Overton Road, Leyton, E10 7PS',
#   'Mrs Melanie Kramer',
#   '24/03/2017',
#   '24/03/2022'],
#  [40506,
#   '24 Eden Road, Walthamstow, E17 9JT',
#   'Ms Sheree Lester',
#   '27/03/2017',
#   '27/03/2022'],
#  [40511,
#   '2 Briarview Court, 71 Handsworth Avenue, Chingford, E4 9PQ',
#   'Ms Joanne Moore',
#   '12/04/2017',
#   '12/04/2022'],
#  [40518,
#   '31 Viking Place, 145 Seymour Road, Leyton, E10 7NB',
#   'Mrs Anne-Marie Stevens',
#   '19/04/2017',
#   '19/04/2022'],
#  [40520,
#   '1b Selby Road, Leytonstone, E11 3LT',
#   'Mr Aqib Sherwani',
#   '19/07/2017',
#   '19/07/2022'],
#  [40521,
#   '6 Fari Court, 4 Tower Mews, Walthamstow, E17 7BF',
#   'Mrs Nasim Rashid',
#   '19/04/2017',
#   '19/04/2022'],
#  [40549,
#   '13 Newbury Road, Chingford, E4 9JH',
#   'Mr PETER JENNINGS',
#   '05/12/2017',
#   '05/12/2022'],
#  [40551,
#   '84a Cann Hall Road, Leytonstone, E11 3JF',
#   'Mr Waheed Salami',
#   '27/03/2017',
#   '27/03/2022'],
#  [40557,
#   '171a Cann Hall Road, Leytonstone, E11 3NJ',
#   'Mr Chris Morris',
#   '21/04/2017',
#   '21/04/2022'],
#  [40561,
#   'Flat 1 Roxwell Studios, Roxwell Trading Park, Argall Avenue, E10 7QY',
#   'Mr Jon Polledri',
#   '01/06/2018',
#   '01/06/2023'],
#  [40598,
#   '49 Forest Drive, Woodford Green, IG8 9NG',
#   'Mr Geoffrey Bent',
#   '31/03/2017',
#   '31/03/2022'],
#  [40599,
#   '50 Forest Drive, Woodford Green, IG8 9NG',
#   'Mr james bent',
#   '31/03/2017',
#   '31/03/2022'],
#  [40600,
#   '48 Forest Drive, Woodford Green, IG8 9NG',
#   'Mr james bent',
#   '21/03/2017',
#   '21/03/2022'],
#  [40601,
#   '47 Forest Drive, Woodford Green, IG8 9NG',
#   'Mr james bent',
#   '20/03/2017',
#   '20/03/2022'],
#  [40608,
#   '46 Eden Road, Walthamstow, E17 9JT',
#   'Mr Richard Brunsden',
#   '20/03/2017',
#   '20/03/2022'],
#  [40612,
#   'Ground Floor Flat, 31 Glenthorne Road, Walthamstow, E17 7AP',
#   'Mr Christendath Seearam',
#   '16/03/2017',
#   '16/03/2022'],
#  [40618,
#   '53 New Road, Chingford, E4 9EU',
#   'Mr Michael Gwilliam',
#   '10/04/2017',
#   '10/04/2022'],
#  [40627,
#   'Flat B, 2 Lyndhurst Drive, Leyton, E10 6JD',
#   'Miss Victoria Woolhead',
#   '10/04/2017',
#   '10/04/2022'],
#  [40628,
#   '83a Grange Park Road, Leyton, E10 5ER',
#   'Mrs Tessa Rowan',
#   '10/05/2017',
#   '10/05/2022'],
#  [40631,
#   '283 Sansom Road, Leytonstone, E11 3HQ',
#   'Mr Colin Grant',
#   '07/11/2017',
#   '07/11/2022'],
#  [40641,
#   'Flat 29, The Technical Institute, 1a Adelaide Road, Leyton, E10 5NN',
#   'Mr Jon Polledri',
#   '14/03/2019',
#   '14/03/2024'],
#  [40642,
#   'Flat 33, The Technical Institute, 1a Adelaide Road, Leyton, E10 5NN',
#   'Mr Jon Polledri',
#   '29/06/2017',
#   '29/06/2022'],
#  [40644,
#   '21 Belton Road, Leytonstone, E11 3JD',
#   'Miss michelle grant',
#   '19/04/2017',
#   '19/04/2021'],
#  [40652,
#   '21 Ranelagh Road, Leytonstone, E11 3JW',
#   'Miss Luella Wright',
#   '06/04/2017',
#   '06/04/2022'],
#  [40660,
#   'Flat 32, The Technical Institute, 1a Adelaide Road, Leyton, E10 5NN',
#   'Mr Jon Polledri',
#   '15/06/2017',
#   '15/06/2022'],
#  [40676,
#   '46 Farmer Road, Leyton, E10 5DH',
#   'Mrs Winsome Joy Semper',
#   '05/04/2017',
#   '05/04/2022'],
#  [40677,
#   '27, 6 Church Hill, Walthamstow, E17 3AG',
#   'Mr khuram pervez',
#   '31/07/2017',
#   '31/07/2022'],
#  [40683,
#   '13 Viking Place, 145 Seymour Road, Leyton, E10 7NB',
#   'Mr UCB Home Loans',
#   '05/04/2017',
#   '05/04/2022'],
#  [40691,
#   '49 Selby Road, Leytonstone, E11 3LS',
#   'Mr Michael Murdoch',
#   '20/04/2017',
#   '20/04/2022'],
#  [40697,
#   'Ground Floor Flat 1, 68 Northcote Road, Walthamstow, E17 7DU',
#   'Mr Shokat Ali',
#   '24/04/2017',
#   '24/04/2022'],
#  [40698,
#   '138 Northcote Road, Walthamstow, E17 7EB',
#   'Mr mohammed ali',
#   '20/04/2017',
#   '20/04/2022'],
#  [40699,
#   '51 Farnborough Avenue, Walthamstow, E17 6HX',
#   'Mr mohammed ali',
#   '24/04/2017',
#   '24/04/2022'],
#  [40700,
#   '33 Elmfield Road, Walthamstow, E17 7HJ',
#   'Mr mohammed ali',
#   '12/04/2017',
#   '12/04/2022'],
#  [40704,
#   '84 Cann Hall Road, Leytonstone, E11 3JF',
#   'Mr Waheed Salami',
#   '24/04/2017',
#   '24/04/2022'],
#  [40715,
#   'First Floor Flat 2, 2 Woodend Road, Walthamstow, E17 4JS',
#   'Mr Shokat Ali',
#   '24/04/2017',
#   '24/04/2022'],
#  [40716,
#   'Ground Floor Flat 1, 71 Skeltons Lane, Leyton, E10 5BT',
#   'Mr Shokat Ali',
#   '21/04/2017',
#   '21/04/2022'],
#  [40717,
#   'Ground Floor Flat 1, 2 Woodend Road, Walthamstow, E17 4JS',
#   'Mr Shokat Ali',
#   '24/04/2017',
#   '24/04/2022'],
#  [40720,
#   'First Floor Flat 2, 71 Skeltons Lane, Leyton, E10 5BT',
#   'Mr Shokat Ali',
#   '18/04/2017',
#   '18/04/2022'],
#  [40739,
#   'Second Floor Front Flat, 628a Lea Bridge Road, Leyton, E10 6AP',
#   'Mr Jack Goode',
#   '14/06/2017',
#   '14/06/2022'],
#  [40741,
#   'Second Floor Rear Flat, 628a Lea Bridge Road, Leyton, E10 6AP',
#   'Mr Jack Goode',
#   '14/06/2017',
#   '14/06/2022'],
#  [40776,
#   '44 Roberts Road, Walthamstow, E17 4LR',
#   'Mr Zahid Raja',
#   '16/05/2017',
#   '16/05/2022'],
#  [40797,
#   'Flat 28, The Technical Institute, 1a Adelaide Road, Leyton, E10 5NN',
#   'Mr Jon Polledri',
#   '21/06/2017',
#   '21/06/2022'],
#  [40798,
#   'Flat 34, The Technical Institute, 1a Adelaide Road, Leyton, E10 5NN',
#   'Mr Jon Polledri',
#   '21/06/2017',
#   '21/06/2022'],
#  [40819,
#   'Ground Floor Flat 1, 105 Manor Road, Leyton, E10 7HN',
#   'Mrs Netsanet Solomon-Marday',
#   '21/09/2017',
#   '21/09/2022'],
#  [40837,
#   '27 Pembar Avenue, Walthamstow, E17 6HN',
#   'Miss yan yan yu',
#   '13/06/2017',
#   '13/06/2022'],
#  [40852,
#   '61 Latchingdon Court, 26 Forest Road, Walthamstow, E17 6JT',
#   'Mr Zuber Majid',
#   '19/04/2017',
#   '19/04/2022'],
#  [40877,
#   'Ground Floor Flat 1, 148 Cann Hall Road, Leytonstone, E11 3NH',
#   'Ms Frances Manning',
#   '13/10/2017',
#   '13/10/2022'],
#  [40887,
#   'First Floor Flat 2, 28 Richmond Road, Leytonstone, E11 4BA',
#   'Mr Orasom Udeozo',
#   '04/07/2017',
#   '04/07/2022'],
#  [40889,
#   '55 Forest View Road, Walthamstow, E17 4EJ',
#   'Mr Khalil Ahmed',
#   '17/05/2017',
#   '17/05/2022'],
#  [40900,
#   '38 Matlock Road, Leyton, E10 6BU',
#   'Mrs Martina Schimmelpenning',
#   '15/05/2017',
#   '15/05/2022'],
#  [40964,
#   '47 Riverhead Close, Walthamstow, E17 5PY',
#   'Mrs Olayinka Owa',
#   '15/05/2017',
#   '15/05/2022'],
#  [40975,
#   '148 Brettenham Road, Walthamstow, E17 5BA',
#   'Mr Valjinder Singh Virdee',
#   '28/03/2019',
#   '28/03/2024'],
#  [40998,
#   '46 Raglan Road, Walthamstow, E17 9EE',
#   'Mr Ahmed Gazi',
#   '05/05/2017',
#   '05/05/2022'],
#  [41024,
#   'First Floor Flat 2, 303 Cann Hall Road, Leytonstone, E11 3NL',
#   'Mr Bramber Properties Limited',
#   '28/04/2017',
#   '28/04/2022'],
#  [41067,
#   'Ground Floor Flat 1, 28 Beacontree Road, Leytonstone, E11 3AX',
#   'Mrs Gillian Duncan',
#   '16/05/2017',
#   '16/05/2022'],
#  [41076,
#   'Flat A, 46a St James Street, Walthamstow, E17 7PE',
#   'Mr Kenneth Gaffney',
#   '08/05/2017',
#   '08/05/2022'],
#  [41083,
#   '98 Bedford Road, Walthamstow, E17 4PU',
#   'Ms Beata Sochon',
#   '24/04/2017',
#   '24/04/2022'],
#  [41085,
#   '257 Harrow Road, Leytonstone, E11 3QA',
#   'Mr Ajay Goel',
#   '24/04/2017',
#   '24/04/2022'],
#  [41102,
#   'Flat 2 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '21/07/2017',
#   '21/07/2022'],
#  [41103,
#   'Flat 3 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '21/07/2017',
#   '21/07/2022'],
#  [41104,
#   'Flat 4 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '21/07/2017',
#   '21/07/2022'],
#  [41106,
#   'Ground Floor Flat, 105 Blackhorse Lane, Walthamstow, E17 6DJ',
#   'Mr Hasan Younis',
#   '16/05/2017',
#   '16/05/2022'],
#  [41124,
#   '4 The Green Walk, Chingford, E4 7ER',
#   'Mr Patrick Kane',
#   '17/05/2017',
#   '17/05/2022'],
#  [41128,
#   '27a Manor Road, Leyton, E10 7AL',
#   'Mr Naveed Ahmed',
#   '17/05/2017',
#   '17/05/2022'],
#  [41131,
#   'First Floor Flat, 105 Blackhorse Lane, Walthamstow, E17 6DJ',
#   'Mr Hasan Younis',
#   '16/05/2017',
#   '16/05/2022'],
#  [41132,
#   'Flat 5 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '21/07/2017',
#   '21/07/2022'],
#  [41133,
#   'Flat 8 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '25/07/2017',
#   '25/07/2022'],
#  [41135,
#   'Flat 10 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '25/07/2017',
#   '25/07/2022'],
#  [41136,
#   'Flat 11 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '25/07/2017',
#   '25/07/2022'],
#  [41138,
#   'Flat 13 Roxwell Studios, Argall Avenue, Leyton, E10 7QY',
#   'Mr Jon Polledri',
#   '25/07/2017',
#   '25/07/2022'],
#  [41148,
#   'Flat A, 319 Hoe Street, Walthamstow, E17 9BD',
#   'Mr Ajaz Nawaz',
#   '17/05/2017',
#   '17/05/2022'],
#  [41151,
#   'Flat B, 319 Hoe Street, Walthamstow, E17 9BD',
#   'Mr Ajaz Nawaz',
#   '18/05/2017',
#   '18/05/2022'],
#  [41152,
#   'Flat C, 319 Hoe Street, Walthamstow, E17 9BD',
#   'Mr Ajaz Nawaz',
#   '18/05/2017',
#   '18/05/2022'],
#  [41160,
#   '25 Belmont Park Road, Leyton, E10 6AU',
#   'Mr Hasan Younis',
#   '10/05/2017',
#   '10/05/2022'],
#  [41168,
#   '5 Nelson Road, Chingford, E4 9AP',
#   'Mr Stephen Griffiths',
#   '18/05/2017',
#   '18/05/2022'],
#  [41172,
#   '338 Markhouse Road, Walthamstow, E17 8EF',
#   'Mr Terry Robertson',
#   '17/05/2017',
#   '17/05/2022'],
#  [41194,
#   '71 Clacton Road, Walthamstow, E17 8AP',
#   'Mr Tim Brocklehurst',
#   '01/06/2017',
#   '01/06/2022'],
#  [41198,
#   '137 Grange Park Road, Leyton, E10 5ET',
#   'Ms Eleanor Walls',
#   '07/09/2017',
#   '07/09/2022'],
#  [41199,
#   'Ground Floor Rear Flat, 134 Vicarage Road, Leyton, E10 5DX',
#   'Mr Shokat Ali',
#   '05/06/2017',
#   '05/06/2022'],
#  [41200,
#   'First Floor Flat, 134 Vicarage Road, Leyton, E10 5DX',
#   'Mr Shokat Ali',
#   '05/06/2017',
#   '05/06/2022'],
#  [41201,
#   'Second Floor Flat, 134 Vicarage Road, Leyton, E10 5DX',
#   'Mr Shokat Ali',
#   '05/06/2017',
#   '05/06/2022'],
#  [41202,
#   '142 Northcote Road, Walthamstow, E17 7EB',
#   'Mr Shokat Ali',
#   '05/06/2017',
#   '05/06/2022'],
#  [41203,
#   'Ground Floor, 280 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Shokat Ali',
#   '16/06/2017',
#   '16/06/2022'],
#  [41204,
#   'First Floor Flat, 280 High Road Leytonstone, Leytonstone, E11 3HS',
#   'Mr Shokat Ali',
#   '16/06/2017',
#   '16/06/2022'],
#  [41206,
#   '64a Maynard Road, Walthamstow, E17 9JG',
#   'Mr Zoubir Hammoudi',
#   '30/05/2017',
#   '30/05/2022'],
#  [41209,
#   'First Floor Flat, 305 Higham Hill Road, Walthamstow, E17 5RG',
#   'Mr Shokat Ali',
#   '05/06/2017',
#   '05/06/2022'],
#  [41230,
#   'Ground Floor Flat 1, 74 Capworth Street, Leyton, E10 7HA',
#   'Mr Hasan Younis',
#   '10/05/2017',
#   '10/05/2022'],
#  [41231,
#   'First Floor Flat 2, 74 Capworth Street, Leyton, E10 7HA',
#   'Mr Hasan Younis',
#   '10/05/2017',
#   '10/05/2022'],
#  [41238,
#   '50 George Road, Chingford, E4 8NF',
#   'Mr Amir Latif',
#   '13/06/2017',
#   '13/06/2022'],
#  [41249,
#   'Ground Floor Flat 1, 1 Frith Road, Leytonstone, E11 4EX',
#   'Ms Natalia Ozherelyeva',
#   '01/06/2017',
#   '01/06/2022'],
#  [41254,
#   '68 Pentire Road, Walthamstow, E17 4BZ',
#   'Mr Howard Joseph',
#   '06/06/2017',
#   '06/06/2022'],
#  [41262,
#   '111 Grange Park Road, Leyton, E10 5ER',
#   'Mr Gary Tomlin',
#   '05/12/2019',
#   '05/12/2024'],
#  [41285,
#   '44 Diana Road, Walthamstow, E17 5LF',
#   'Ms Gill Davies',
#   '31/05/2017',
#   '31/05/2022'],
#  [41288,
#   '183b Lea Bridge Road, Leyton, E10 7PN',
#   'Mr DINCER GUL',
#   '09/12/2019',
#   '09/12/2024'],
#  [41325,
#   '24 Russell Road, Chingford, E4 8HB',
#   'Miss Jeanette Hale',
#   '19/05/2017',
#   '19/05/2022'],
#  [41338,
#   '6 Fairlop Court, 63 Fairlop Road, Leytonstone, E11 1BG',
#   'Mr UCB Home Loans',
#   '15/06/2017',
#   '15/06/2022'],
#  [41341,
# ...
#   '09/07/2018',
#   '09/07/2023'],
#  [46255,
#   '131a Wallwood Road, Leytonstone, E11 1AQ',
#   'Miss Kezia Campbell',
#   '04/07/2018',
#   '04/07/2023'],
#  [46258,
#   '30a Hatherley Road, Walthamstow, E17 6SF',
#   'Mrs Alexis Smith',
#   '05/07/2018',
#   '05/07/2023'],
#  [46263,
#   'Ground Floor Flat 1, 303 Cann Hall Road, Leytonstone, E11 3NL',
#   'Mrs Shelagh Daboul',
#   '15/06/2018',
#   '15/06/2023'],
#  [46303,
#   'First Floor Flat, 25 Hatherley Road, Walthamstow, E17 6SE',
#   'Miss Beverly Jones',
#   '22/05/2018',
#   '22/05/2023'],
#  [46338,
#   'Ground Floor Flat, 63 Buxton Road, Walthamstow, E17 7EH',
#   'Mr Rizwaan Khan',
#   '04/06/2018',
#   '04/06/2023'],
#  [46339,
#   '30a Normanshire Drive, Chingford, E4 9HF',
#   'Mr Cafer ARSLAN',
#   '02/07/2018',
#   '02/07/2023'],
#  [46342,
#   '745a High Road Leytonstone, Leytonstone, E11 4QS',
#   'Mr Trevor Hollinshead',
#   '21/05/2018',
#   '21/05/2023'],
#  [46348,
#   'Ground Floor Flat 1, 187 Colchester Road, Leyton, E10 6HG',
#   'Mr Saqib Hussain',
#   '19/06/2018',
#   '19/06/2023'],
#  [46353,
#   '26 Drysdale Avenue, Chingford, E4 7NJ',
#   'Mr Martin Ricketts',
#   '15/05/2018',
#   '15/05/2023'],
#  [46372,
#   '147 Ramsay Road, Forest Gate, E7 9EP',
#   'Miss Anna Muir',
#   '07/06/2018',
#   '07/06/2023'],
#  [46381,
#   '10 Claymore Court, 244 Billet Road, Walthamstow, E17 5HF',
#   'Miss Arona Sarwar',
#   '05/07/2018',
#   '05/07/2023'],
#  [46386,
#   '18 Oak Hill Gardens, Woodford Green, IG8 9DY',
#   'Ms Bilkis Master',
#   '08/06/2018',
#   '08/06/2023'],
#  [46389,
#   '5 Forster Road, Walthamstow, E17 8AU',
#   'Mr Gabor Laszlo Tibor Bathory',
#   '08/06/2018',
#   '08/06/2023'],
#  [46390,
#   'Flat 6, 23 Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Kittrell',
#   '05/09/2018',
#   '05/09/2023'],
#  [46402,
#   '167a High Street, Walthamstow, E17 7BX',
#   'Mr Sam Khalique',
#   '18/07/2018',
#   '18/07/2023'],
#  [46403,
#   '167b High Street, Walthamstow, E17 7BX',
#   'Mr Sam Khalique',
#   '02/07/2018',
#   '02/07/2023'],
#  [46411,
#   '125 Beresford Road, Chingford, E4 6EF',
#   'Mr James Salmon',
#   '11/09/2018',
#   '11/09/2023'],
#  [46421,
#   '11 Perth Road, Leyton, E10 7PA',
#   'Mr Oliver Carruthers',
#   '02/07/2018',
#   '02/07/2023'],
#  [46425,
#   'Flat 5, Ashley House, 1a Westerham Road, Leyton, E10 7AE',
#   'Mr Glenn Hooker',
#   '14/06/2018',
#   '14/06/2023'],
#  [46436,
#   '88 Stocksfield Road, Walthamstow, E17 3LJ',
#   'Mr Shazid Ameen',
#   '05/06/2018',
#   '05/06/2023'],
#  [46439,
#   '24 Lockwood Place, Chingford, E4 9AD',
#   'Mr Andrew Van Loen',
#   '07/06/2018',
#   '07/06/2023'],
#  [46456,
#   '61 Jesse Road, Leyton, E10 6NN',
#   'Mr neal richards',
#   '05/06/2018',
#   '05/06/2023'],
#  [46461,
#   '88 James Lane, Leyton, E10 6HL',
#   'Mr Malkeet Pandhal',
#   '15/05/2018',
#   '15/05/2023'],
#  [46463,
#   'Flat 2, 23 Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Kittrell',
#   '23/11/2018',
#   '23/11/2023'],
#  [46475,
#   '21 Long Leys, Chingford, E4 9LW',
#   'Mr Darin Gosling',
#   '15/05/2018',
#   '15/05/2023'],
#  [46476,
#   '126 Bramley Close, Walthamstow, E17 6EG',
#   'Mr Patrick French',
#   '15/05/2018',
#   '15/05/2023'],
#  [46508,
#   '6 Kenilworth Avenue, Walthamstow, E17 4PE',
#   'Miss Thilaka Moorthy',
#   '18/05/2018',
#   '18/05/2023'],
#  [46512,
#   'Flat 1, 130 Sewardstone Road, Chingford, E4 7PY',
#   'Mr Paul Mottram',
#   '19/09/2018',
#   '19/09/2023'],
#  [46513,
#   'Flat 2, 130 Sewardstone Road, Chingford, E4 7PY',
#   'Mr Paul Mottram',
#   '19/09/2018',
#   '19/09/2023'],
#  [46520,
#   '6 Barclay Road, Leytonstone, E11 3DG',
#   'Mr Ebrahim Mansoor',
#   '04/06/2018',
#   '04/06/2023'],
#  [46522,
#   'Flat 4, 23 Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Kittrell',
#   '30/11/2018',
#   '30/11/2023'],
#  [46538,
#   'Flat 3, 23 Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Kittrell',
#   '23/11/2018',
#   '23/11/2023'],
#  [46540,
#   'Flat 5, 23 Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Fletcher',
#   '23/11/2018',
#   '23/11/2023'],
#  [46541,
#   '23a Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Kittrell',
#   '23/11/2018',
#   '23/11/2023'],
#  [46542,
#   '2a Brantwood Close, Walthamstow, E17 3DY',
#   'Miss Gemma Fogerty',
#   '29/05/2018',
#   '29/05/2023'],
#  [46545,
#   '18 Chamberlain Place, Walthamstow, E17 6AY',
#   'Miss carol mcleod',
#   '24/05/2018',
#   '24/05/2023'],
#  [46561,
#   '29b Higham Hill Road, Walthamstow, E17 6EA',
#   'Mrs Linda Simpole',
#   '15/04/2020',
#   '15/04/2021'],
#  [46566,
#   '91 Goldsmith Road, Leyton, E10 5EX',
#   'Mr Edward Caton',
#   '27/07/2018',
#   '27/07/2023'],
#  [46571,
#   '33 St Georges Road, Leyton, E10 5RH',
#   'Mr daniel jeffreys',
#   '22/05/2018',
#   '22/05/2023'],
#  [46586,
#   '294 Higham Hill Road, Walthamstow, E17 5RG',
#   'Mrs Audrey Banyikidde',
#   '30/05/2018',
#   '30/05/2023'],
#  [46596,
#   '35 Beaufort Close, Chingford, E4 9XF',
#   'Mrs Deborah Shealy',
#   '12/06/2018',
#   '12/06/2023'],
#  [46612,
#   'Flat 1, 99a Peterborough Road, Leyton, E10 6EL',
#   'Mr Eldridge Cooke',
#   '28/06/2018',
#   '28/06/2023'],
#  [46619,
#   '23 Church Hill, Walthamstow, E17 3AB',
#   'Ms Suzanne Kittrell',
#   '17/07/2018',
#   '17/07/2023'],
#  [46633,
#   '64 Livingstone Road, Walthamstow, E17 9AX',
#   'Mr Mudassar Ali',
#   '05/07/2018',
#   '05/07/2023'],
#  [46647,
#   'First Floor Flat 2, 187 Colchester Road, Leyton, E10 6HG',
#   'Mr Saqib Hussain',
#   '17/07/2018',
#   '17/07/2023'],
#  [46659,
#   '35 King Edward Road, Walthamstow, E17 6HY',
#   'Mr Shokat Ali',
#   '07/09/2018',
#   '07/09/2023'],
#  [46662,
#   '19 Kings Road, Chingford, E4 7HP',
#   'Mr HARJI VARSANI',
#   '20/08/2018',
#   '20/08/2023'],
#  [46664,
#   '292 Higham Hill Road, Walthamstow, E17 5RG',
#   'Mrs Surayia Ahmed',
#   '20/08/2018',
#   '20/08/2023'],
#  [46666,
#   '164 Blackhorse Lane, Walthamstow, E17 6AA',
#   'Mr Andrew David Watts',
#   '29/01/2019',
#   '29/01/2024'],
#  [46668,
#   '278 Chingford Road, Walthamstow, E17 5AL',
#   'Mr Jeganathan Pushpanathan',
#   '20/08/2018',
#   '20/08/2023'],
#  [46680,
#   '53 Westdown Road, Stratford, E15 2BZ',
#   'Mr Milon Miah',
#   '20/08/2018',
#   '20/08/2023'],
#  [46681,
#   '43 Adelaide Road, Leyton, E10 5NW',
#   'Mr Milon Miah',
#   '20/08/2018',
#   '20/08/2023'],
#  [46685,
#   '55 Brookfield Avenue, Walthamstow, E17 9ER',
#   'Miss Pamela Allanson',
#   '23/05/2018',
#   '23/05/2023'],
#  [46715,
#   '62 Dyson Road, Leytonstone, E11 1LZ',
#   'Miss Sarah Munt',
#   '10/08/2018',
#   '10/08/2023'],
#  [46723,
#   '50 Hainault Road, Leytonstone, E11 1EE',
#   'Mr ZAHUR CHAUDHRY',
#   '09/11/2018',
#   '09/11/2023'],
#  [46741,
#   '125 Hampton Road, Chingford, E4 8NS',
#   'Mr David Murphy',
#   '20/08/2018',
#   '20/08/2023'],
#  [46798,
#   '170a Hainault Road, Leytonstone, E11 1EP',
#   'Mr ANDREW MCCONNELL',
#   '21/03/2019',
#   '21/03/2024'],
#  [46801,
#   '12 Selwyn Court, 2 Yunus Khan Close, Walthamstow, E17 8XE',
#   'Mr Gordon Milne',
#   '17/12/2018',
#   '17/12/2023'],
#  [46803,
#   '3 Brewster Road, Leyton, E10 6RG',
#   'Mr Jon Rogers',
#   '09/10/2019',
#   '09/10/2024'],
#  [46815,
#   '37b Wolsey Avenue, Walthamstow, E17 6RE',
#   'Mr Christophe McGlade',
#   '14/02/2019',
#   '14/02/2024'],
#  [46824,
#   'Ground Floor Flat 1, 50 Westdown Road, Stratford, E15 2DA',
#   'Mr YASIR IQBAL',
#   '05/12/2018',
#   '05/12/2023'],
#  [46826,
#   '30 Salisbury Road, Chingford, E4 6TA',
#   'Mr Neville Asphall',
#   '13/06/2018',
#   '13/08/2023'],
#  [46830,
#   '170 Hainault Road, Leytonstone, E11 1EP',
#   'Mr colin gourley',
#   '12/12/2018',
#   '12/12/2023'],
#  [46857,
#   'Flat 4, 173a Wood Street, Walthamstow, E17 3NU',
#   'Mr Kamran Raza',
#   '11/10/2019',
#   '11/10/2024'],
#  [46864,
#   '78 Lancaster Road, Walthamstow, E17 6AJ',
#   'Mr mohammed ali',
#   '15/10/2019',
#   '15/10/2024'],
#  [46868,
#   'Ground Floor Flat, 35 Chingford Road, Walthamstow, E17 4PW',
#   'Mr AYUB KHAN',
#   '19/12/2018',
#   '19/12/2023'],
#  [46872,
#   '12 Margarets Court, 195 Hainault Road, Leytonstone, E11 1EY',
#   'Mr Veera Reddy Jayar',
#   '13/03/2019',
#   '13/03/2024'],
#  [46873,
#   '24 Byron Road, Walthamstow, E17 4SW',
#   'Mr Ismail Mutlu',
#   '06/09/2018',
#   '06/09/2023'],
#  [46888,
#   'First Floor Flat 2, 87 Murchison Road, Leyton, E10 6NA',
#   'Mr Warren Pongchai',
#   '23/07/2018',
#   '23/07/2023'],
#  [46892,
#   '23 Chewton Road, Walthamstow, E17 7DW',
#   'Mr mario campanelli',
#   '24/06/2019',
#   '24/06/2024'],
#  [46916,
#   'Flat 5, 93-95 Orford Road, Walthamstow, E17 9QR',
#   'Mr Tristan Lark',
#   '14/12/2018',
#   '14/12/2023'],
#  [46917,
#   '14 Cecil House, 445 Chingford Road, Walthamstow, E17 5AQ',
#   'Mrs Karena Lucas',
#   '17/08/2018',
#   '17/08/2023'],
#  [46925,
#   '6 Howard Mansions, Forest Road, Walthamstow, E17 4NA',
#   'Mr Aiden Garner',
#   '21/02/2019',
#   '21/02/2024'],
#  [46936,
#   '17 Frances Road, Chingford, E4 9DH',
#   'Mrs Amanda Linton',
#   '06/11/2018',
#   '06/11/2023'],
#  [46937,
#   '142 Chingford Road, Walthamstow, E17 4PL',
#   'Mr Christopher Neylan',
#   '24/08/2018',
#   '24/08/2023'],
#  [46948,
#   'Flat 2, 1 Connaught Avenue, Chingford, E4 7AE',
#   'Mrs Sallie Biss',
#   '31/08/2018',
#   '31/08/2023'],
#  [46949,
#   '382a Hoe Street, Walthamstow, E17 9AA',
#   'Mrs Together Roache',
#   '04/02/2020',
#   '04/02/2025'],
#  [46955,
#   'Flat 6, 619a Lea Bridge Road, Leyton, E10 6AJ',
#   'Mr Soner Mustafa',
#   '26/02/2020',
#   '26/02/2025'],
#  [46963,
#   '398a Hale End Road, Chingford, E4 9PB',
#   'Mr Mark Cushway',
#   '27/07/2018',
#   '27/07/2023'],
#  [46975,
#   'First Floor Flat, 3 Higham Place, Walthamstow, E17 6DD',
#   'Mr Lokambikai Pathmanathan',
#   '17/10/2019',
#   '17/10/2024'],
#  [46976,
#   '67 Cavendish Drive, Leytonstone, E11 1DL',
#   'Mr Mahbub Shah',
#   '31/01/2020',
#   '31/01/2025'],
#  [46995,
#   'Flat 3, 622A High Road Leytonstone, Leytonstone, E11 3DA',
#   'Mrs Meiyun Wu',
#   '15/10/2019',
#   '15/10/2024'],
#  [46996,
#   'Flat 5, 622A High Road Leytonstone, Leytonstone, E11 3DA',
#   'Mrs Meiyun Wu',
#   '15/10/2019',
#   '15/10/2024'],
#  [46999,
#   '78 Chewton Road, Walthamstow, E17 7DN',
#   'Ms Charmaine Gray',
#   '17/08/2018',
#   '17/08/2023'],
#  [47003,
#   '9 Drayton House, 6 Drayton Road, Leytonstone, E11 4AS',
#   'Mr Michael Culver',
#   '17/08/2018',
#   '17/08/2023'],
#  [47009,
#   'Ground Floor Flat Rear, 305 Higham Hill Road, Walthamstow, E17 5RG',
#   'Mrs s ali',
#   '15/10/2019',
#   '15/10/2024'],
#  [47013,
#   '2 Chester Mews, 135a Chingford Road, Walthamstow, E17 4PN',
#   'Mr Andrew Smith',
#   '15/08/2018',
#   '15/08/2023'],
#  [47019,
#   '18 King Court, 25 Capworth Street, Leyton, E10 5AJ',
#   'Mr thedchanamoorthy shanmugavadivel',
#   '20/06/2018',
#   '20/06/2023'],
#  [47034,
#   '348d High Road Leyton, Leyton, E10 6QE',
#   'Mr Mohammad Bhatti',
#   '19/11/2019',
#   '19/11/2024'],
#  [47038,
#   '133a Claude Road, Leyton, E10 6NF',
#   'PEIWEN LIU',
#   '23/01/2019',
#   '23/01/2024'],
#  [47052,
#   '40 Hall Road, Stratford, E15 2BT',
#   'Mr Olanrewaju Odunlami',
#   '03/08/2018',
#   '03/08/2023'],
#  [47053,
#   '12 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Mr Shamsul Rois',
#   '30/08/2018',
#   '30/08/2023'],
#  [47055,
#   'Flat 2, 83 Whipps Cross Road, Leytonstone, E11 1NJ',
#   'Ms Natasha Gowans',
#   '22/01/2019',
#   '22/01/2024'],
#  [47060,
#   '13 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Mr Shamsul Rois',
#   '30/08/2018',
#   '30/08/2023'],
#  [47062,
#   '14 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Mr Shamsul Rois',
#   '29/10/2018',
#   '29/10/2023'],
#  [47063,
#   '16 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Mr Shamsul Rois',
#   '30/08/2018',
#   '30/08/2023'],
#  [47065,
#   '17 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Rois Group Ltd',
#   '04/07/2018',
#   '04/07/2023'],
#  [47066,
#   '18 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Rois Group Ltd',
#   '30/08/2018',
#   '30/08/2023'],
#  [47067,
#   '19 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Mr Shamsul Rois',
#   '20/08/2018',
#   '20/08/2023'],
#  [47068,
#   '20 Prestige House, 38 Clifford Road, Walthamstow, E17 4FX',
#   'Mr Shamsul Rois',
#   '30/08/2018',
#   '30/08/2023'],
#  [47083,
#   '3 Atwell Close, Leyton, E10 6AG',
#   'Miss Suzanne Vu',
#   '21/06/2018',
#   '21/06/2023'],
#  [47086,
#   'Ground Floor Flat 1, 19 Manor Road, Leyton, E10 7AL',
#   'Mr Carl Owusu',
#   '22/08/2018',
#   '22/08/2023'],
#  [47098,
#   'Flat 2, 99a Peterborough Road, Leyton, E10 6EL',
#   'Mr Eldridge Cooke',
#   '17/09/2018',
#   '17/09/2023'],
#  [47101,
#   '85 Manor Road, Leyton, E10 7HN',
#   'Mrs Farida Husain',
#   '19/09/2018',
#   '19/09/2023'],
#  [47108,
#   '4 Waterloo Road, Leyton, E10 7HR',
#   'Mr Kevin Marshall',
#   '05/09/2018',
#   '05/09/2023'],
#  [47127,
#   'First Floor Flat 2, 15 Fladgate Road, Leytonstone, E11 1LX',
#   'Mr Alastair Woolley',
#   '30/08/2018',
#   '30/08/2023'],
#  [47144,
#   '34 Capworth Street, Leyton, E10 7HA',
#   'Mr Dursun Celik',
#   '07/11/2019',
#   '07/11/2024'],
#  [47147,
#   '34a Capworth Street, Leyton, E10 7HA',
#   'Mr Kent Reliance',
#   '07/11/2019',
#   '07/11/2024'],
#  [47151,
#   '49 Grove Road, Walthamstow, E17 9BL',
#   'Mr mazhar khamkar',
#   '03/09/2018',
#   '03/09/2023'],
#  [47164,
#   '57a Crownfield Road, Stratford, E15 2AB',
#   'Mr Usman Patel',
#   '04/09/2018',
#   '04/09/2023'],
#  [47165,
#   '55a Crownfield Road, Stratford, E15 2AB',
#   'Mr Usman Patel',
#   '06/12/2018',
#   '06/12/2023'],
#  [47166,
#   '55c Crownfield Road, Stratford, E15 2AB',
#   'Mr Usman Patel',
#   '27/11/2018',
#   '27/11/2023'],
#  [47178,
#   '7 Buttermere Close, Stratford, E15 2DN',
#   'Mr Godiva Mortgages',
#   '03/04/2020',
#   '03/04/2025'],
#  [47283,
#   '2 Hedge Court, 103 Hainault Road, Leytonstone, E11 1DU',
#   'Mr Graham Golder',
#   '18/10/2018',
#   '18/10/2023'],
#  [47324,
#   '44 Spencer Road, Walthamstow, E17 4BD',
#   'Miss Cynthia Kirton',
#   '23/10/2018',
#   '23/10/2023'],
#  [47410,
#   '30 Morgan Avenue, Walthamstow, E17 3PL',
#   'Ms Hanna Qazi',
#   '27/06/2018',
#   '27/06/2023'],
#  [47411,
#   '17 Nutfield Road, Stratford, E15 2DG',
#   'Mr victor martinez',
#   '31/01/2020',
#   '31/01/2025'],
#  [47432,
#   '78 Hainault Court, Forest Rise, Walthamstow, E17 3NW',
#   'Mr Nathan Barrow',
#   '18/11/2019',
#   '18/11/2024'],
#  [47451,
#   '72a Kingswood Road, Leytonstone, E11 1SF',
#   'Theydons Property Services Theydons',
#   '14/11/2018',
#   '14/11/2023'],
#  [47453,
#   'Ground Floor Flat 1, 12a Norlington Road, Leytonstone, E11 4BG',
#   'Theydons Property Services Theydons',
#   '14/11/2018',
#   '14/11/2023'],
#  [47457,
#   '9 Centro Court, 707 High Road Leytonstone, Leytonstone, E11 4QZ',
#   'Theydons Property Services Ltd',
#   '08/11/2018',
#   '08/11/2023'],
#  [47461,
#   '33c Westerham Road, Leyton, E10 7AE',
#   'Theydons Property Services Ltd',
#   '12/11/2018',
#   '12/11/2023'],
#  [47463,
#   '41a Hainault Road, Leytonstone, E11 1EB',
#   'Mrs Nessah Dustagheer',
#   '18/11/2019',
#   '18/11/2024'],
#  [47465,
#   '10 Chamberlain Place, Walthamstow, E17 6AY',
#   'Ms Sarah Metcalfe',
#   '21/08/2018',
#   '21/08/2023'],
#  [47466,
#   '7 Forest View, Chingford, E4 7AY',
#   'Theydons Property Services Ltd',
#   '12/11/2018',
#   '12/11/2023'],
#  [47467,
#   '24 Woodbridge House, 145 Mornington Road, Leytonstone, E11 3DZ',
#   'Theydons Property Services Theydons',
#   '14/11/2018',
#   '14/11/2023'],
#  [47468,
#   '69 Kingsdown Road, Leytonstone, E11 3LW',
#   'Theydons Property Services Ltd',
#   '14/11/2018',
#   '14/11/2023'],
#  [47473,
#   '18b Kingswood Road, Leytonstone, E11 1SE',
#   'Theydons Property Services Theydons',
#   '14/11/2018',
#   '14/11/2023'],
#  [47474,
#   '55 Matcham Road, Leytonstone, E11 3LE',
#   'Theydons Property Services Theydons',
#   '14/11/2018',
#   '14/11/2023'],
#  [47475,
#   '76 Oak Hill, Woodford Green, IG8 9PE',
#   'Mr Daniel Fowler',
#   '21/08/2018',
#   '21/08/2023'],
#  [47477,
#   '7 Swallow Court, 78 Kingswood Road, Leytonstone, E11 1SQ',
#   'Theydons Property Services Theydons',
#   '14/11/2018',
#   '14/11/2023'],
#  [47484,
#   '55 Westdown Road, Stratford, E15 2BZ',
#   'Mr Surgeon Ali',
#   '18/11/2019',
#   '18/11/2024'],
#  [47492,
#   '100 Carlton Road, Walthamstow, E17 5RE',
#   'Mrs Danielle Jessenberger',
#   '21/08/2018',
#   '21/08/2023'],
#  [47514,
#   'Ground Floor Flat, 34 Campbell Road, Walthamstow, E17 6RR',
#   'Century 21 Harris & Martin Limited',
#   '14/10/2019',
#   '14/10/2024'],
#  [47516,
#   '76 Kimberley Road, Chingford, E4 6DQ',
#   'Mr Zuber Majid',
#   '04/10/2018',
#   '04/10/2023'],
#  [47517,
#   '77 Kimberley Road, Chingford, E4 6DQ',
#   'Mr Zuber Majid',
#   '29/08/2018',
#   '29/08/2023'],
#  [47537,
#   '13a Argyle Road, Stratford, E15 1UJ',
#   'Mr Mirko Speri',
#   '12/09/2018',
#   '12/09/2023'],
#  [47553,
#   '3 Belle Vue Lodge, 24 Connaught Avenue, Chingford, E4 7AB',
#   'Mr Simon Edwards',
#   '02/08/2018',
#   '02/08/2023'],
#  ...]

# %%
from gspread_pandas import Spread

file_name = "http://stats.idre.ucla.edu/stat/data/binary.csv"
df = pd.read_csv(file_name)

# 'Example Spreadsheet' needs to already exist and your user must have access to it
spread = Spread('hmo_registers', creds=ServiceAccountCredentials.from_json_keyfile_name(filepath_cred, scope))
# This will ask to authenticate if you haven't done so before

# Display available worksheets
spread.sheets

# Save DataFrame to worksheet 'New Test Sheet', create it first if it doesn't exist
spread.df_to_sheet(df, index=False, sheet='New Test Sheet', start='A2', replace=True)
spread.update_cells('A1', 'A1', ['Created by:'])

# %%
# sheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())
